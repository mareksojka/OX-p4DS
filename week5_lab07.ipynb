# %% [markdown]
# # Lab 7: MapReduce
#
# Welcome to lab 7! This exercise is another free-form challenge, just like with lab 4 that was focused on the London 2012 athletes dataset. This time, I want you to see if you can answer some questions on a dataset, but only by using the MapReduce programming model.
#
# <img src="mapreduce.jpg"/>
#
# First, run the cell below to view a sample of 10 rows from the text file `nasa_access_log_aug95_sample.txt`.

# %%
# The function islice thats the list of lines returned by the 
# open( ... ) command and returns a slice of only 10 of those lines.

from itertools import islice
with open('nasa_access_log_aug95_sample.txt') as file_pointer:
    for line in list(islice(file_pointer, 10)):
        print(line)
# Out:
# 159.142.165.138 - - [15/Aug/1995:11:03:22 -0400] "GET /shuttle/missions/sts-73/sts-73-patch-small.gif HTTP/1.0" 200 4179
#
# 134.131.38.18 - - [22/Aug/1995:13:43:38 -0400] "GET /shuttle/missions/sts-73/sts-73-patch-small.gif HTTP/1.0" 200 4179
#
# os2c14.aca.ilstu.edu - - [31/Aug/1995:21:47:11 -0400] "GET /shuttle/missions/sts-69/sts-69-patch-small.gif HTTP/1.0" 200 8083
#
# suba01.suba.com - - [24/Aug/1995:04:48:23 -0400] "GET /htbin/wais.pl?TISP HTTP/1.0" 200 1349
#
# 146.138.145.170 - - [08/Aug/1995:16:30:51 -0400] "GET /shuttle/missions/sts-62/sts-62-patch-small.gif HTTP/1.0" 200 14385
#
# pizza.innet.net - - [24/Aug/1995:18:22:52 -0400] "GET /history/apollo/images/apollo-logo1.gif HTTP/1.0" 200 1173
#
# uplherc.upl.com - - [01/Aug/1995:00:00:10 -0400] "GET /images/WORLD-logosmall.gif HTTP/1.0" 304 0
#
# 205.129.171.133 - - [16/Aug/1995:14:13:00 -0400] "GET /images/launch-logo.gif HTTP/1.0" 200 1713
#
# icenet.blackice.com.au - - [16/Aug/1995:07:52:55 -0400] "GET /history/apollo/images/apollo.gif HTTP/1.0" 200 28847
#
# qa2.silverplatter.com - - [23/Aug/1995:12:55:43 -0400] "GET /history/mercury/mr-3/mr-3-patch-small.gif HTTP/1.0" 200 19084

# %% [markdown]
# ## The Challenge (part A)
#
# Unlike the previous exercises, I have not provided you with a CSV file. This is a file that contains lines of text that is the format output by the Apache HTTP Server -- one of the most popular Web servers on the Internet -- where the lines are in a standardised format (see the [Common Log Format](https://en.wikipedia.org/wiki/Common_Log_Format) for details), but not comma-separated.
#
# The first part of the challenge is to create a CSV file from this log file. As an example, I have written a few lines below that work on replacing ` - - ` with a comma `,`. You can use what you have alread learned about string replacement to try and create what you think is a sensible split of columns, split by commas.

# %%
from itertools import islice
with open('nasa_access_log_aug95_sample.txt') as file_pointer:
    for line in list(islice(file_pointer, 10)):
        # The following line simply takes the line read and does a string replacement
        print(line.replace(' - - ', ' ').replace(',',' ').replace('"','').replace('[',' ').replace(']',' ').split())
# Out:
# ['159.142.165.138', '15/Aug/1995:11:03:22', '-0400', 'GET', '/shuttle/missions/sts-73/sts-73-patch-small.gif', 'HTTP/1.0', '200', '4179']
# ['134.131.38.18', '22/Aug/1995:13:43:38', '-0400', 'GET', '/shuttle/missions/sts-73/sts-73-patch-small.gif', 'HTTP/1.0', '200', '4179']
# ['os2c14.aca.ilstu.edu', '31/Aug/1995:21:47:11', '-0400', 'GET', '/shuttle/missions/sts-69/sts-69-patch-small.gif', 'HTTP/1.0', '200', '8083']
# ['suba01.suba.com', '24/Aug/1995:04:48:23', '-0400', 'GET', '/htbin/wais.pl?TISP', 'HTTP/1.0', '200', '1349']
# ['146.138.145.170', '08/Aug/1995:16:30:51', '-0400', 'GET', '/shuttle/missions/sts-62/sts-62-patch-small.gif', 'HTTP/1.0', '200', '14385']
# ['pizza.innet.net', '24/Aug/1995:18:22:52', '-0400', 'GET', '/history/apollo/images/apollo-logo1.gif', 'HTTP/1.0', '200', '1173']
# ['uplherc.upl.com', '01/Aug/1995:00:00:10', '-0400', 'GET', '/images/WORLD-logosmall.gif', 'HTTP/1.0', '304', '0']
# ['205.129.171.133', '16/Aug/1995:14:13:00', '-0400', 'GET', '/images/launch-logo.gif', 'HTTP/1.0', '200', '1713']
# ['icenet.blackice.com.au', '16/Aug/1995:07:52:55', '-0400', 'GET', '/history/apollo/images/apollo.gif', 'HTTP/1.0', '200', '28847']
# ['qa2.silverplatter.com', '23/Aug/1995:12:55:43', '-0400', 'GET', '/history/mercury/mr-3/mr-3-patch-small.gif', 'HTTP/1.0', '200', '19084']

# %% [markdown]
# Modify the code below to write out the `nasa_access_log_aug95_sample.csv` file with your string replacements to turn the input into a CSV file that can be read using `pandas`.

# %%
list_df=[]
from itertools import islice
with open('nasa_access_log_aug95_sample.txt') as input_file_pointer:
    with open('nasa_access_log_aug95_sample.csv', 'w') as output_file_pointer:
        for line in input_file_pointer:
            output_file_pointer.write("{line}".format(line=line.replace(' - - ', ',').replace('"','').replace('[',' ').replace(']','').split()))
            data=line.replace(' - - ', ',').replace(',',' ').replace('"','').replace('[',' ').replace(']','').split()
            if len(data)==8:
                list_df.append(data)

# %% [markdown]
# ### For unknown reason read_csv wouldn't load the DataFrame, so I create a DataFrame strait from txt file in cell above list_df which is a list of lists of values, and in cell below DataFrame df1 from list_df

# %%
import pandas as pd
import numpy as np
#df = pd.read_csv('nasa_access_log_aug95_short.csv', error_bad_lines=False, warn_bad_lines=False)
#df.columns = ['Address', 'DateTime','Timezone','Method','File','HTTP','Status','Size']
#df

# %%
df1=pd.DataFrame(list_df,columns=['Address', 'DateTime','Timezone','Method','File','HTTP','Status','Size'])

# %%
df1.tail()
# Out:
#                        Address              DateTime Timezone Method  \
# 98334     gordon-nsc2.army.mil  07/Aug/1995:14:52:43    -0400    GET
# 98335  novix.casi.sti.nasa.gov  23/Aug/1995:18:07:10    -0400    GET
# 98336          cerruti.idx.com  08/Aug/1995:14:19:28    -0400    GET
# 98337    arcadia.ece.miami.edu  28/Aug/1995:15:41:58    -0400    GET
# 98338           204.149.228.71  18/Aug/1995:06:08:54    -0400    GET
#
#                                                File      HTTP Status   Size
# 98334  /shuttle/missions/sts-69/mission-sts-69.html  HTTP/1.0    200  11264
# 98335        /history/apollo/apollo-4/apollo-4.html  HTTP/1.0    200   3542
# 98336                       /images/launch-logo.gif  HTTP/1.0    200   1713
# 98337                   /images/WORLD-logosmall.gif  HTTP/1.0    200    669
# 98338  /shuttle/missions/sts-69/mission-sts-69.html  HTTP/1.0    200  11996

# %% [markdown]
# ## Qusetion 1 -  Which files were most popular in terms of GET requests?
# ### Mapper function

# %%
Files_Map=[]
for row in df1.loc[:,['File','Method']].iterrows():
    Files_Map.append((row[1].values[0],row[1].values[1]))
Files_Map
# Out:
# [('/shuttle/missions/sts-73/sts-73-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-73/sts-73-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/htbin/wais.pl?TISP', 'GET'),
#  ('/shuttle/missions/sts-62/sts-62-patch-small.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/history/apollo/images/apollo.gif', 'GET'),
#  ('/history/mercury/mr-3/mr-3-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-70/movies/woodpecker.mpg', 'GET'),
#  ('/history/apollo/apollo-11/images/69HC635.GIF', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-70/images/DSC-95EC-0001.gif', 'GET'),
#  ('/shuttle/missions/sts-71/mission-sts-71.html', 'GET'),
#  ('/history/gemini/gemini.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/history/apollo/apollo-11/apollo-11.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-71/movies/sts-71-launch.mpg', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-71/sts-71-patch-small.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/resources/orbiters/discovery-logo.gif', 'GET'),
#  ('/history/early-astronauts.txt', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-68/news/sts-68-mcc-06.txt', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/elv/DELTA/dedesc.htm', 'GET'),
#  ('/', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/shuttle/missions/51-f/images/85HC290.GIF', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/shuttle/countdown/images/lccteam.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/history/mercury/ma-8/ma-8-patch-small.gif', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?401,288', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/facilities/tour.html', 'GET'),
#  ('/shuttle/missions/sts-71/movies/sts-71-launch-3.mpg', 'GET'),
#  ('/shuttle/missions/sts-68/news/sts-68-mcc-07.txt', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/shuttle/resources/orbiters/challenger.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/facts/faq11.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/history/skylab/skylab-small.gif', 'GET'),
#  ('/history/apollo/apollo-13/apollo-13-info.html', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/images/NASA-logo.gif', 'GET'),
#  ('/elv/elvhead3.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-1/mission-sts-1.html', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-68/news/sts-68-mcc-08.txt', 'GET'),
#  ('/shuttle/technology/sts-newsref/sts_coord.html', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/shuttle/countdown/tour.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/software/winvn/wvsmall.gif', 'GET'),
#  ('/shuttle/missions/sts-73/sts-73-patch-small.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/construct.gif', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/elv/ATLAS_CENTAUR/atc69s.jpg', 'GET'),
#  ('/persons/nasa-cm/jmd.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/history/gemini/gemini-1/gemini-1.html', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/history/apollo/images/footprint-logo.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/software/winvn/userguide/docscont.gif', 'GET'),
#  ('/elv/updated.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/elv/elvhead2.gif', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/sts_asm.html', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/elv/elvpage.htm', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/history/astp/flight-summary.txt', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/elv/updated.gif', 'GET'),
#  ('/htbin/wais.pl?EURECA', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?122,285', 'GET'),
#  ('/shuttle/missions/sts-71/images/KSC-95EC-0912.jpg', 'GET'),
#  ('/shuttle/missions/sts-70/sts-70-patch-small.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/images/images.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-70/o-ring-problem.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/history/apollo/apollo-4/movies/', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/resources/orbiters/enterprise.gif', 'GET'),
#  ('/images/construct.gif', 'GET'),
#  ('/shuttle/resources/orbiters/discovery.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/history/mercury/mercury-overview.txt', 'GET'),
#  ('/shuttle/technology/sts-newsref/sts-rcs.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/icons/menu.xbm', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-71/movies/movies.html', 'GET'),
#  ('/shuttle/missions/sts-69/images/images.html', 'GET'),
#  ('/shuttle/missions/sts-71/images/KSC-95EC-0951.jpg', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/facts/faq01.html', 'GET'),
#  ('/shuttle/resources/orbiters/challenger-logo.gif', 'GET'),
#  ('/shuttle/resources/orbiters/columbia-logo.gif', 'GET'),
#  ('/shuttle/resources/orbiters/endeavour.html', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/images/mercury-logo.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/persons/astronauts/q-to-t/TrulyRH.txt', 'GET'),
#  ('/history/apollo/apollo.html', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/sts-eclss-wcl.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/icons/menu.xbm', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?60,162', 'GET'),
#  ('/shuttle/countdown/liftoff.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/elv/struct.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-70/sts-70-patch-small.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/movies/movies.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/software/winvn/bluemarb.gif', 'GET'),
#  ('/history/mercury/mercury.html', 'GET'),
#  ('/history/apollo/images/apollo-small.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/et.html', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/pub/winvn/release.txt', 'GET'),
#  ('/shuttle/resources/orbiters/atlantis.html', 'GET'),
#  ('/shuttle/missions/51-l/51-l-patch-small.gif', 'GET'),
#  ('/shuttle/resources/orbiters/discovery-logo.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/history/apollo/apollo-13/images/70HC418.GIF', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/shuttle/missions/sts-70/mission-sts-70.html', 'GET'),
#  ('/history/apollo/images/footprint-small.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/history/apollo/as-201/as-201.html', 'GET'),
#  ('/history/apollo/apollo-1/news/', 'GET'),
#  ('/elv/elvpage.htm', 'GET'),
#  ('/statistics/1995/bkup/Mar95_full.html', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/countdown/lps/bkup-intg/bkup-intg.html', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/htbin/cdt_clock.pl', 'GET'),
#  ('/elv/elvpage.htm', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/shuttle-patch-logo.gif', 'GET'),
#  ('/images/shuttle-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-69/images/KSC-95EC-1032.jpg', 'GET'),
#  ('/shuttle/missions/sts-68/mission-sts-68.html', 'GET'),
#  ('/elv/vidpicp.htm', 'GET'),
#  ('/software/winvn/bluemarb.gif', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-71/movies/sts-71-mir-dock-2.mpg', 'GET'),
#  ('/shuttle/missions/sts-71/mission-sts-71.html', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/51-l/images/', 'GET'),
#  ('/htbin/wais.pl', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/elv/struct.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/software/winvn/winvn.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/shuttle/countdown/liftoff.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/51-l/news/', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/history/apollo/apollo-11/apollo-11-patch-small.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/icons/sound.xbm', 'GET'),
#  ('/shuttle/missions/sts-70/sts-70-patch-small.gif', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/shuttle/countdown/liftoff.html', 'GET'),
#  ('/shuttle/missions/sts-53/', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/shuttle/missions/sts-69/images/KSC-95EC-1032.gif', 'GET'),
#  ('/images/kscmap-tiny.gif', 'GET'),
#  ('/shuttle/resources/orbiters/columbia.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/elv/endball.gif', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?389,291', 'GET'),
#  ('/shuttle/countdown/video/livevideo2.gif', 'GET'),
#  ('/icons/blank.xbm', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/facilities/tour.html', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/elv/ATLAS_CENTAUR/acsuns.jpg', 'GET'),
#  ('/images/USA-logosmall.gif', 'HEAD'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/history/apollo/apollo.html', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/history/apollo/apollo.html', 'GET'),
#  ('/images/construct.gif', 'GET'),
#  ('/history/apollo/images/apollo-insignia.jpg', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/shuttle/missions/sts-73/mission-sts-73.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-71/movies/movies.html', 'GET'),
#  ('/shuttle/countdown/video/livevideo2.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-69/images/images.html', 'GET'),
#  ('/images/shuttle-patch-small.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/shuttle/missions/sts-69/images/images.html', 'GET'),
#  ('/', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/software/winvn/wvsmall.gif', 'GET'),
#  ('/images/rss.gif', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/icons/text.xbm', 'GET'),
#  ('/sales@summagraphics.com', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-68/mission-sts-68.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-71/movies/movies.html', 'GET'),
#  ('/history/apollo/apollo-11/images/index.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-71/images/KSC-95EC-0911.txt', 'GET'),
#  ('/shuttle/resources/orbiters/endeavour.html', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/software/winvn/bluemarb.gif', 'GET'),
#  ('/history/apollo/images/footprint-small.gif', 'GET'),
#  ('/images/shuttle-patch-small.gif', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/software/winvn/wvsmall.gif', 'GET'),
#  ('/icon/new01.gif', 'GET'),
#  ('/finance/collsm1.gif', 'GET'),
#  ('/shuttle/missions/sts-70/images/KSC-95EC-1016.jpg', 'GET'),
#  ('/shuttle/resources/orbiters/endeavour-logo.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/shuttle/missions/sts-68/news/sts-68-mcc-17.txt', 'GET'),
#  ('/history/history.html', 'GET'),
#  ('/history/apollo/apollo-13/apollo-13-patch-small.gif', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/gemini-logo.gif', 'GET'),
#  ('/history/mercury/mr-3/mr-3-patch-small.gif', 'GET'),
#  ('/facilities/lc39a.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/shuttle/technology/images/srb_mod_compare_3-small.gif', 'GET'),
#  ('/history/apollo/apollo-13/apollo-13.html', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/shuttle/countdown/lps/back.gif', 'GET'),
#  ('/images/launch-small.gif', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/icons/blank.xbm', 'GET'),
#  ('/elv/new01.gif', 'GET'),
#  ('/images/slf.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/htbin/wais.pl', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/history/apollo/images/footprint-logo.gif', 'GET'),
#  ('/history/apollo/apollo-17/images/', 'GET'),
#  ('/images/lc39a-logo.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/shuttle/missions/sts-71/movies/sts-71-tcdt-crew-walkout.mpg', 'GET'),
#  ('/history/apollo/apollo-13/apollo-13-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/history/apollo/apollo-13/', 'GET'),
#  ('/shuttle/missions/sts-69/images/KSC-95EC-0694.jpg', 'GET'),
#  ('/images/lc39a-logo.gif', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/htbin/wais.pl', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/liftoff.html', 'GET'),
#  ('/', 'GET'),
#  ('/shuttle/missions/sts-32/mission-sts-32.html', 'GET'),
#  ('/history/apollo/images/apollo-small.gif', 'GET'),
#  ('/htbin/wais.pl', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/51-l/51-l-info.html', 'GET'),
#  ('/', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/history/apollo/images/footprint-small.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/stsover-launch.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/software/winvn/winvn.gif', 'GET'),
#  ('/htbin/cdt_clock.pl', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/kscmap-tiny.gif', 'GET'),
#  ('/shuttle/missions/sts-69/movies/movies.html', 'GET'),
#  ('/history/apollo/images/apollo-logo.gif', 'GET'),
#  ('/images/construct.gif', 'GET'),
#  ('/shuttle/missions/sts-69/movies/ws-animation-onorbit.mpg', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/history/apollo/apollo-11/apollo-11-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/software/winvn/userguide/2_3_3.htm', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/shuttle/missions/', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/images/construct.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/history/apollo/apollo-17/images/72HC670.GIF', 'GET'),
#  ('/icons/blank.xbm', 'GET'),
#  ('/shuttle/missions/sts-42/sts-42-patch.jpg', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/movies/ws-animation-onorbit.mpg', 'GET'),
#  ('/history/mercury/ma-7/ma-7.html', 'GET'),
#  ('/shuttle/missions/sts-71/sts-71-patch-small.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/elv/SCOUT/sampexs.jpg', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/history/apollo/apollo.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/history/history.html', 'GET'),
#  ('/shuttle/technology/sts-newsref/stsref-toc.html', 'GET'),
#  ('/shuttle/missions/61-c/mission-61-c.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/kscmap-small.gif', 'GET'),
#  ('/shuttle/countdown/lps/images/console1.gif', 'GET'),
#  ('/', 'GET'),
#  ('/shuttle/missions/sts-72/news', 'GET'),
#  ('/history/apollo/apollo-17/apollo-17.html', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/movies/ws-animation-deploy.mpg', 'GET'),
#  ('/history/apollo/images/apollo-logo.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-74/sts-74-info.html', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/finance/tour.gif', 'GET'),
#  ('/software/winvn/wvsmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/procurement/business/ciao.htm', 'GET'),
#  ('/icons/menu.xbm', 'GET'),
#  ('/icons/unknown.xbm', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-70/images/KSC-95EC-0649.jpg', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/elv/TITAN/mars2s.jpg', 'GET'),
#  ('/shuttle/resources/orbiters/orbiters-logo.gif', 'GET'),
#  ('/shuttle/technology/images/srb_mod_compare_6-small.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/kscmap-tiny.gif', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/history/apollo/sa-10/sa-10.html', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/shuttle/resources/orbiters/endeavour-logo.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-64/sts-64-patch-small.gif', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/resources/orbiters/enterprise-logo.gif', 'GET'),
#  ('/facilities/lc39a.html', 'GET'),
#  ('/shuttle/missions/sts-70/images/KSC-95EC-0515.gif', 'GET'),
#  ('/history/apollo/apollo-15/images/71HC1144.GIF', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/stsref-toc.html', 'GET'),
#  ('/icons/menu.xbm', 'GET'),
#  ('/shuttle/missions/sts-missions-flown.txt', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/STS-5.JPG', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/lc39a-logo.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/history/skylab/skylab-logo.gif', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/images/launch-small.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/icons/menu.xbm', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/images/images.html', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/shuttle/technology/images/srb_mod_compare_1-small.gif', 'GET'),
#  ('/software/winvn/winvn.gif', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/shuttle/missions/sts-70/images/KSC-95EC-1012.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/images/images.html', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/history/apollo/apollo-5/apollo-5-info.html', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/shuttle/missions/sts-70/mission-sts-70.html', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/', 'GET'),
#  ('/shuttle/missions/sts-56/sts-56-patch-small.gif', 'GET'),
#  ('/history/apollo/apollo-17/', 'GET'),
#  ('/facts/facts.html', 'GET'),
#  ('/history/apollo/images/apollo-logo.gif', 'GET'),
#  ('/htbin/cdt_clock.pl', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/history/apollo/apollo-13/', 'GET'),
#  ('/shuttle/missions/sts-41/sts-41-patch-small.gif', 'GET'),
#  ('/shuttle/countdown/video/livevideo2.gif', 'GET'),
#  ('/shuttle/missions/61-c/61-c-patch-small.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/history/gemini/images/gemini-logo.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-59/mission-sts-59.html', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-70/sts-70-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/images/lps-small.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/history/apollo/apollo.html', 'GET'),
#  ('/shuttle/missions/sts-70/images/KSC-95EC-1016.jpg', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/countdown/liftoff.html', 'GET'),
#  ('/', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/history/apollo/sa-3/sa-3.html', 'GET'),
#  ('/history/apollo/flight-summary.txt', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/icons/unknown.xbm', 'GET'),
#  ('/history/apollo/images/footprint-small.gif', 'GET'),
#  ('/history/apollo/apollo.html', 'GET'),
#  ('/shuttle/countdown/liftoff.html', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/stsref-toc.html', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/vab-medium.gif', 'GET'),
#  ('/software/winvn/bluemarb.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/shuttle/missions/51-l/images/850128.GIF', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/software/winvn/winvn.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/htbin/cdt_clock.pl', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/elv/TITAN/mars3s.jpg', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/shuttle/missions/sts-49/sts-49-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-69/images/images.html', 'GET'),
#  ('/icons/blank.xbm', 'GET'),
#  ('/shuttle/missions/sts-69/endeavour-pad-prelaunch-8-31-95.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/facts/faq.html', 'GET'),
#  ('/persons/astronauts/u-to-z/WilliamsDE.txt', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/', 'GET'),
#  ('/facilities/saef2.html', 'GET'),
#  ('/shuttle/resources/orbiters/challenger-logo.gif', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/history/gemini/gemini-2/gemini-2-info.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/elv/updated.gif', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?393,290', 'GET'),
#  ('/shuttle/countdown/lps/fr.html', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?345,286', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-59/sts-59-patch-small.gif', 'GET'),
#  ('/pub/winvn/readme.txt', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/technology/images/srb_mod_compare_1-small.gif', 'GET'),
#  ('/shuttle/missions/sts-70/movies/movies.html', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?63,161', 'GET'),
#  ('/icons/menu.xbm', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/history/apollo/apollo.html', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/history/apollo/apollo-1/apollo-1-info.html', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/htbin/cdt_clock.pl', 'GET'),
#  ('/history/apollo/images/apollo-small.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/software/winvn/wvsmall.gif', 'GET'),
#  ('/icons/unknown.xbm', 'GET'),
#  ('/shuttle/countdown/liftoff.html', 'GET'),
#  ('/shuttle/missions/sts-69/movies/ws-animation-deploy.mpg', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/41-d/', 'GET'),
#  ('/shuttle/countdown', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-71/movies/sts-71-launch-3.mpg', 'GET'),
#  ('/history/apollo/images/footprint-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/icons/text.xbm', 'GET'),
#  ('/shuttle/missions/sts-74/mission-sts-74.html', 'GET'),
#  ('/images/lc39a-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-63/mission-sts-63.html', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/shuttle/missions/sts-69/movies/movies.html', 'GET'),
#  ('/history/apollo/apollo-13/apollo-13-patch-small.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/countdown/video/livevideo.jpeg', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/countdown/video/livevideo2.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/spacelab.html', 'GET'),
#  ('/shuttle/resources/orbiters/orbiters-logo.gif', 'GET'),
#  ('/facilities/mlp.html', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/icons/unknown.xbm', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/history/apollo/images/footprint-logo.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-70/images/KSC-95EC-0515.gif', 'GET'),
#  ('/history/apollo/apollo-11/apollo-11.html', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/history/astp/astp-patch-small.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/countdown/lps/fr.html', 'GET'),
#  ('/shuttle/missions/sts-70/images/KSC-95EC-0705.txt', 'GET'),
#  ('/software/winvn/bluemarb.gif', 'GET'),
#  ('/history/mercury/mr-3/mr-3.html', 'GET'),
#  ('/elv/ATLAS_CENTAUR/atlas.gif', 'GET'),
#  ('/images/vab-small.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/stsref-toc.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/shuttle/missions/51-d/mission-51-d.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-72/sts-72-info.html', 'GET'),
#  ('/shuttle/missions/sts-69/liftoff.html', 'GET'),
#  ('/shuttle/missions/sts-69/images/images.html', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/sts_asm.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-68/sts-68-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-36/sts-36-patch-small.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/history/apollo/apollo-13/apollo-13.html', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/elv/whnew.htm', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-70/sts-70-patch-small.gif', 'GET'),
#  ('/shuttle/resources/orbiters/columbia.html', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/countdown/video/livevideo.jpeg', 'GET'),
#  ('/history/apollo/apollo-17/apollo-17.html', 'GET'),
#  ('/shuttle/technology/sts-newsref/sts-lcc.html', 'GET'),
#  ('/shuttle/technology/images/srb_mod_compare_6-small.gif', 'GET'),
#  ('/shuttle/missions/sts-71/sts-71-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-66/mission-sts-66.html', 'GET'),
#  ('/history/apollo/images/footprint-small.gif', 'GET'),
#  ('/history/apollo/images/little-joe.gif', 'GET'),
#  ('/history/early-astronauts.txt', 'GET'),
#  ('/shuttle/missions/sts-69/movies/ws-animation-deploy.mpg', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-55/sts-55-patch-small.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?183,287', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/', 'GET'),
#  ('/shuttle/missions/sts-76/mission-sts-76.html', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/images/shuttle-patch-logo.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/shuttle/resources/orbiters/orbiters-logo.gif', 'GET'),
#  ('/shuttle/missions/51-l/news/', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/history/apollo/images/footprint.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/', 'GET'),
#  ('/images/mercury-logo.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/100th.html', 'GET'),
#  ('/', 'GET'),
#  ('/images/', 'GET'),
#  ('/elv/struct.gif', 'GET'),
#  ('/shuttle/resources/orbiters/endeavour.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/shuttle/missions/sts-71/images/KSC-95EC-0911.jpg', 'GET'),
#  ('/facilities/mlp.html', 'GET'),
#  ('/', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/', 'GET'),
#  ('/images/kscmap-tiny.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/htbin/wais.pl?images%2Cearth', 'GET'),
#  ('/shuttle/missions/41-b/', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/shuttle/resources/orbiters/discovery.html', 'GET'),
#  ('/shuttle/missions/sts-69/images/KSC-95EC-0969.gif', 'GET'),
#  ('/history/history.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/history/apollo/flight-summary.txt', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?185,285', 'GET'),
#  ('/history/apollo/apollo-12/videos/moonflag.mpg', 'GET'),
#  ('/images/cdrom-1-95/img0082.jpg', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/software/winvn/wvsmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/stsref-toc.html', 'GET'),
#  ('/shuttle/missions/sts-71/sts-71-patch-small.gif', 'GET'),
#  ('/software/', 'GET'),
#  ('/history/apollo/images/APOLLO-logosmall.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-34/movies/', 'GET'),
#  ('/history/apollo/apollo-1/apollo-1-info.html', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/shuttle/technology/images/sts_spec_6-small.gif', 'GET'),
#  ('/images/kscmap-small.gif', 'GET'),
#  ('/software/webadmin/payload.txt', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/elv/DELTA/del181s.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/shuttle/missions/51-j/mission-51-j.html', 'GET'),
#  ('/shuttle/missions/sts-32/mission-sts-32.html', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/history/gemini/gemini.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/shuttle/technology/sts-newsref/stsover-launch.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/history/skylab/skylab.html', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-73/sts-73-patch-small.gif', 'GET'),
#  ('/icons/menu.xbm', 'GET'),
#  ('/shuttle/missions/sts-69/images/images.html', 'GET'),
#  ('/shuttle/missions/sts-1/sts-1-patch-small.gif', 'GET'),
#  ('/history/apollo/apollo-1/images/67HC33a.gif', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/history/apollo/apollo-11/images/69HC973.GIF', 'GET'),
#  ('/pub/winvn/release.txt', 'GET'),
#  ('/shuttle/technology/sts-newsref/sts-subs.html', 'GET'),
#  ('/history/apollo/apollo-sa.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/elv/new01.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/movies/movies.html', 'GET'),
#  ('/history/apollo/apollo-1/sounds/', 'GET'),
#  ('/shuttle/missions/sts-70/mission-sts-70.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/shuttle/resources/orbiters/atlantis.gif', 'GET'),
#  ('/shuttle/missions/sts-61/mission-sts-61.html', 'GET'),
#  ('/shuttle/missions/sts-68/images/ksc-upclose.gif', 'GET'),
#  ('/images/construct.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/shuttle/resources/orbiters/orbiters-logo.gif', 'GET'),
#  ('/history/apollo/flight-summary.txt', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/software/winvn/winvn.html', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/images/kscmap-tiny.gif', 'GET'),
#  ('/shuttle/missions/sts-39/docs/', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/images/kscmap-tiny.gif', 'GET'),
#  ('/elv/updated.gif', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/shuttle-patch-logo.gif', 'GET'),
#  ('/history/apollo/apollo-12/movies/', 'GET'),
#  ('/shuttle/resources/orbiters/challenger.html', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/shuttle/missions/41-d/images/84HC598.GIF', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/shuttle/technology/sts-newsref/sts-msfc.html', 'GET'),
#  ('/images/cm-map.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/history/apollo/apollo-13/apollo-13-patch-small.gif', 'GET'),
#  ('/history/apollo/apollo-1/apollo-1.html', 'GET'),
#  ('/images/lc39a-logo.gif', 'GET'),
#  ('/history/gemini/gemini-xii/gemini-xii-info.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-74/mission-sts-74.html', 'GET'),
#  ('/shuttle/missions/sts-72/sts-72-patch-small.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/elv/PEGASUS/minpeg1.gif', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/shuttle/countdown/video/livevideo2.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/shuttle/technology/images/tal_abort_2-small.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-56/sts-56-patch-small.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/htbin/wais.pl?STS-59', 'GET'),
#  ('/shuttle/missions/sts-1/mission-sts-1.html', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?71,153', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/shuttle/countdown/lps/fr.gif', 'GET'),
#  ('/shuttle/missions/sts-69/liftoff.html', 'GET'),
#  ('/', 'GET'),
#  ('/images/ksclogosmall.gif', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/history/apollo/images/footprint-logo.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/history/apollo/images/apollo-logo1.gif', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-35/mission-sts-35.html', 'GET'),
#  ('/shuttle/countdown/liftoff.html', 'GET'),
#  ('/cgi-bin/imagemap/countdown69?284,290', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/icons/unknown.xbm', 'GET'),
#  ('/history/apollo/apollo-13/images/70HC507.GIF', 'GET'),
#  ('/history/apollo/sa-1/sa-1-patch-small.gif', 'GET'),
#  ('/icons/menu.xbm', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/', 'GET'),
#  ('/', 'GET'),
#  ('/images/gemini-logo.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/resources/orbiters/orbiters-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-71/images/KSC-95EC-0423.txt', 'GET'),
#  ('/', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/history/apollo/apollo-1/apollo-1-info.html', 'GET'),
#  ('/shuttle/missions/sts-37/mission-sts-37.html', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/images/launchmedium.gif', 'GET'),
#  ('/shuttle/countdown/video/livevideo2.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-71/images/KSC-95EC-0544.jpg', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-76/mission-sts-76.html', 'GET'),
#  ('/shuttle/countdown/', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/facilities/mlp.html', 'GET'),
#  ('/', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/facts/facts.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/', 'GET'),
#  ('/shuttle/missions/51-l/mission-51-l.html', 'GET'),
#  ('/images/NASA-logosmall.gif', 'GET'),
#  ('/htbin/cdt_main.pl', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/shuttle-patch-small.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/history/apollo/apollo-11/apollo-11-patch.jpg', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-70/sts-70-info.html', 'GET'),
#  ('/shuttle/countdown/video/livevideo2.gif', 'GET'),
#  ('/shuttle/missions/sts-69/count69.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/shuttle/missions/sts-71/sts-71-info.html', 'GET'),
#  ('/shuttle/missions/sts-69/countdown.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/finance/book.gif', 'GET'),
#  ('/elv/new01.gif', 'GET'),
#  ('/elv/endball.gif', 'GET'),
#  ('/persons/astronauts/a-to-d/BoldenCF.txt', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/shuttle/countdown/video/livevideo.jpeg', 'GET'),
#  ('/shuttle/missions/sts-63/mission-sts-63.html', 'GET'),
#  ('/', 'GET'),
#  ('/software/winvn/bluemarb.gif', 'GET'),
#  ('/shuttle/missions/missions.html', 'GET'),
#  ('/shuttle/technology/sts-newsref/sts_eclss.html', 'GET'),
#  ('/ksc.html', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/shuttle/resources/orbiters/columbia.html', 'GET'),
#  ('/shuttle/missions/sts-72/sts-72-patch-small.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/htbin/cdt_clock.pl', 'GET'),
#  ('/images/vab-small.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/images/USA-logosmall.gif', 'GET'),
#  ('/icons/menu.xbm', 'GET'),
#  ('/icons/blank.xbm', 'GET'),
#  ('/shuttle/countdown/images/countclock.gif', 'GET'),
#  ('/history/history.html', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/shuttle/resources/orbiters/orbiters-logo.gif', 'GET'),
#  ('/shuttle/missions/sts-69/sts-69-patch-small.gif', 'GET'),
#  ('/history/apollo/apollo-13/sounds/a13_004.wav', 'GET'),
#  ('/htbin/cdt_clock.pl', 'GET'),
#  ('/shuttle/missions/sts-78/mission-sts-78.html', 'GET'),
#  ('/shuttle/missions/sts-69/endeavour-pad-prelaunch-8-31-95.gif', 'GET'),
#  ('/images/MOSAIC-logosmall.gif', 'GET'),
#  ('/images/ksclogo.gif', 'GET'),
#  ('/icons/image.xbm', 'GET'),
#  ('/images/WORLD-logosmall.gif', 'GET'),
#  ('/shuttle/missions/sts-71/images/KSC-95EC-0950.gif', 'GET'),
#  ('/images/KSC-logosmall.gif', 'GET'),
#  ('/', 'GET'),
#  ('/images/launch-logo.gif', 'GET'),
#  ('/history/apollo/apollo-12/images/69HC1344.GIF', 'GET'),
#  ('/images/ksclogo-medium.gif', 'GET'),
#  ('/shuttle/missions/sts-32/sts-32-patch-small.gif', 'GET'),
#  ('/shuttle/missions/sts-69/mission-sts-69.html', 'GET'),
#  ('/procurement/midrange/notices/equip/rfqmary.htm', 'GET'),
#  ...]

# %% [markdown]
# ### Reducer function

# %%
def Reducer_1(Map):
    Result={}
    for key in Map:
        if key[1]=='GET':
            if key[0] in Result.keys():
                Result[key[0]]+=1
            else:
                Result[key[0]]=1
    return Result

# %%
Q1Result=Reducer_1(Files_Map)
Q1Result
# Out:
# {'/shuttle/missions/sts-73/sts-73-patch-small.gif': 161,
#  '/shuttle/missions/sts-69/sts-69-patch-small.gif': 1509,
#  '/htbin/wais.pl?TISP': 22,
#  '/shuttle/missions/sts-62/sts-62-patch-small.gif': 40,
#  '/history/apollo/images/apollo-logo1.gif': 2378,
#  '/images/WORLD-logosmall.gif': 4212,
#  '/images/launch-logo.gif': 2194,
#  '/history/apollo/images/apollo.gif': 65,
#  '/history/mercury/mr-3/mr-3-patch-small.gif': 78,
#  '/shuttle/missions/sts-70/movies/woodpecker.mpg': 70,
#  '/history/apollo/apollo-11/images/69HC635.GIF': 10,
#  '/shuttle/missions/sts-69/mission-sts-69.html': 1578,
#  '/shuttle/missions/sts-70/images/DSC-95EC-0001.gif': 32,
#  '/shuttle/missions/sts-71/mission-sts-71.html': 210,
#  '/history/gemini/gemini.html': 95,
#  '/history/apollo/apollo-11/apollo-11.html': 213,
#  '/shuttle/missions/sts-71/movies/sts-71-launch.mpg': 140,
#  '/icons/image.xbm': 624,
#  '/ksc.html': 2782,
#  '/images/KSC-logosmall.gif': 4917,
#  '/images/NASA-logosmall.gif': 6193,
#  '/shuttle/missions/sts-71/sts-71-patch-small.gif': 360,
#  '/shuttle/resources/orbiters/discovery-logo.gif': 101,
#  '/history/early-astronauts.txt': 61,
#  '/shuttle/missions/sts-68/news/sts-68-mcc-06.txt': 1,
#  '/images/ksclogosmall.gif': 1846,
#  '/elv/DELTA/dedesc.htm': 11,
#  '/': 1814,
#  '/images/USA-logosmall.gif': 4210,
#  '/images/launchmedium.gif': 1265,
#  '/shuttle/missions/51-f/images/85HC290.GIF': 1,
#  '/shuttle/countdown/images/lccteam.gif': 11,
#  '/shuttle/missions/sts-69/count69.gif': 1529,
#  '/history/mercury/ma-8/ma-8-patch-small.gif': 14,
#  '/cgi-bin/imagemap/countdown69?401,288': 1,
#  '/images/MOSAIC-logosmall.gif': 4216,
#  '/facilities/tour.html': 135,
#  '/shuttle/missions/sts-71/movies/sts-71-launch-3.mpg': 50,
#  '/shuttle/missions/sts-68/news/sts-68-mcc-07.txt': 1,
#  '/htbin/cdt_main.pl': 1083,
#  '/shuttle/resources/orbiters/challenger.html': 135,
#  '/facts/faq11.html': 26,
#  '/history/skylab/skylab-small.gif': 99,
#  '/history/apollo/apollo-13/apollo-13-info.html': 120,
#  '/shuttle/countdown/images/countclock.gif': 783,
#  '/images/NASA-logo.gif': 21,
#  '/elv/elvhead3.gif': 137,
#  '/shuttle/missions/sts-1/mission-sts-1.html': 101,
#  '/shuttle/missions/sts-68/news/sts-68-mcc-08.txt': 1,
#  '/shuttle/technology/sts-newsref/sts_coord.html': 64,
#  '/images/ksclogo-medium.gif': 3942,
#  '/shuttle/countdown/tour.html': 65,
#  '/software/winvn/wvsmall.gif': 552,
#  '/images/construct.gif': 328,
#  '/elv/ATLAS_CENTAUR/atc69s.jpg': 29,
#  '/persons/nasa-cm/jmd.gif': 27,
#  '/history/gemini/gemini-1/gemini-1.html': 17,
#  '/history/apollo/images/footprint-logo.gif': 610,
#  '/software/winvn/userguide/docscont.gif': 23,
#  '/elv/updated.gif': 102,
#  '/elv/elvhead2.gif': 108,
#  '/shuttle/countdown/': 1556,
#  '/shuttle/technology/sts-newsref/sts_asm.html': 268,
#  '/elv/elvpage.htm': 186,
#  '/history/astp/flight-summary.txt': 14,
#  '/htbin/wais.pl?EURECA': 1,
#  '/cgi-bin/imagemap/countdown69?122,285': 1,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0912.jpg': 26,
#  '/shuttle/missions/sts-70/sts-70-patch-small.gif': 298,
#  '/shuttle/missions/sts-69/images/images.html': 338,
#  '/software/winvn/winvn.html': 669,
#  '/shuttle/missions/sts-70/o-ring-problem.gif': 102,
#  '/history/apollo/apollo-4/movies/': 3,
#  '/shuttle/resources/orbiters/enterprise.gif': 6,
#  '/shuttle/resources/orbiters/discovery.html': 99,
#  '/history/mercury/mercury-overview.txt': 21,
#  '/shuttle/technology/sts-newsref/sts-rcs.html': 16,
#  '/icons/menu.xbm': 755,
#  '/shuttle/missions/sts-71/movies/movies.html': 208,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0951.jpg': 23,
#  '/facts/faq01.html': 15,
#  '/shuttle/resources/orbiters/challenger-logo.gif': 118,
#  '/shuttle/resources/orbiters/columbia-logo.gif': 112,
#  '/shuttle/resources/orbiters/endeavour.html': 265,
#  '/images/mercury-logo.gif': 136,
#  '/persons/astronauts/q-to-t/TrulyRH.txt': 1,
#  '/history/apollo/apollo.html': 562,
#  '/shuttle/technology/sts-newsref/sts-eclss-wcl.html': 7,
#  '/cgi-bin/imagemap/countdown69?60,162': 1,
#  '/shuttle/countdown/liftoff.html': 497,
#  '/elv/struct.gif': 112,
#  '/shuttle/missions/sts-69/movies/movies.html': 303,
#  '/software/winvn/bluemarb.gif': 536,
#  '/history/mercury/mercury.html': 120,
#  '/history/apollo/images/apollo-small.gif': 586,
#  '/shuttle/technology/sts-newsref/et.html': 39,
#  '/shuttle/missions/missions.html': 1425,
#  '/pub/winvn/release.txt': 83,
#  '/shuttle/resources/orbiters/atlantis.html': 91,
#  '/shuttle/missions/51-l/51-l-patch-small.gif': 132,
#  '/history/apollo/apollo-13/images/70HC418.GIF': 19,
#  '/shuttle/missions/sts-70/mission-sts-70.html': 271,
#  '/history/apollo/images/footprint-small.gif': 620,
#  '/history/apollo/as-201/as-201.html': 25,
#  '/history/apollo/apollo-1/news/': 16,
#  '/statistics/1995/bkup/Mar95_full.html': 8,
#  '/shuttle/countdown/lps/bkup-intg/bkup-intg.html': 9,
#  '/htbin/cdt_clock.pl': 516,
#  '/images/shuttle-patch-logo.gif': 442,
#  '/images/shuttle-patch-small.gif': 295,
#  '/shuttle/missions/sts-69/images/KSC-95EC-1032.jpg': 81,
#  '/shuttle/missions/sts-68/mission-sts-68.html': 115,
#  '/elv/vidpicp.htm': 35,
#  '/shuttle/missions/sts-71/movies/sts-71-mir-dock-2.mpg': 19,
#  '/shuttle/missions/51-l/images/': 44,
#  '/htbin/wais.pl': 145,
#  '/software/winvn/winvn.gif': 601,
#  '/shuttle/missions/51-l/news/': 37,
#  '/history/apollo/apollo-11/apollo-11-patch-small.gif': 181,
#  '/icons/sound.xbm': 43,
#  '/shuttle/missions/sts-53/': 3,
#  '/shuttle/missions/sts-69/images/KSC-95EC-1032.gif': 58,
#  '/images/kscmap-tiny.gif': 414,
#  '/shuttle/resources/orbiters/columbia.html': 124,
#  '/elv/endball.gif': 112,
#  '/cgi-bin/imagemap/countdown69?389,291': 1,
#  '/shuttle/countdown/video/livevideo2.gif': 434,
#  '/icons/blank.xbm': 815,
#  '/elv/ATLAS_CENTAUR/acsuns.jpg': 25,
#  '/history/apollo/images/apollo-insignia.jpg': 2,
#  '/shuttle/missions/sts-73/mission-sts-73.html': 164,
#  '/images/rss.gif': 91,
#  '/icons/text.xbm': 326,
#  '/sales@summagraphics.com': 2,
#  '/history/apollo/apollo-11/images/index.gif': 13,
#  '/history/apollo/images/apollo-logo.gif': 288,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0911.txt': 1,
#  '/icon/new01.gif': 23,
#  '/finance/collsm1.gif': 72,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1016.jpg': 19,
#  '/shuttle/resources/orbiters/endeavour-logo.gif': 266,
#  '/shuttle/missions/sts-68/news/sts-68-mcc-17.txt': 1,
#  '/history/history.html': 655,
#  '/history/apollo/apollo-13/apollo-13-patch-small.gif': 368,
#  '/images/gemini-logo.gif': 75,
#  '/facilities/lc39a.html': 284,
#  '/shuttle/technology/images/srb_mod_compare_3-small.gif': 169,
#  '/history/apollo/apollo-13/apollo-13.html': 449,
#  '/shuttle/countdown/lps/back.gif': 93,
#  '/images/launch-small.gif': 159,
#  '/elv/new01.gif': 128,
#  '/images/slf.gif': 8,
#  '/history/apollo/apollo-17/images/': 20,
#  '/images/lc39a-logo.gif': 263,
#  '/shuttle/missions/sts-71/movies/sts-71-tcdt-crew-walkout.mpg': 36,
#  '/history/apollo/apollo-13/': 72,
#  '/shuttle/missions/sts-69/images/KSC-95EC-0694.jpg': 94,
#  '/shuttle/missions/sts-69/liftoff.html': 300,
#  '/shuttle/missions/sts-32/mission-sts-32.html': 16,
#  '/shuttle/missions/51-l/51-l-info.html': 56,
#  '/shuttle/technology/sts-newsref/stsover-launch.html': 38,
#  '/shuttle/missions/sts-69/movies/ws-animation-onorbit.mpg': 34,
#  '/software/winvn/userguide/2_3_3.htm': 2,
#  '/shuttle/missions/': 62,
#  '/history/apollo/apollo-17/images/72HC670.GIF': 12,
#  '/shuttle/missions/sts-42/sts-42-patch.jpg': 1,
#  '/history/mercury/ma-7/ma-7.html': 19,
#  '/elv/SCOUT/sampexs.jpg': 31,
#  '/shuttle/technology/sts-newsref/stsref-toc.html': 373,
#  '/shuttle/missions/61-c/mission-61-c.html': 45,
#  '/images/kscmap-small.gif': 140,
#  '/shuttle/countdown/lps/images/console1.gif': 3,
#  '/shuttle/missions/sts-72/news': 8,
#  '/history/apollo/apollo-17/apollo-17.html': 65,
#  '/shuttle/missions/sts-69/movies/ws-animation-deploy.mpg': 75,
#  '/shuttle/missions/sts-74/sts-74-info.html': 26,
#  '/finance/tour.gif': 47,
#  '/procurement/business/ciao.htm': 1,
#  '/icons/unknown.xbm': 309,
#  '/shuttle/missions/sts-70/images/KSC-95EC-0649.jpg': 15,
#  '/elv/TITAN/mars2s.jpg': 36,
#  '/shuttle/resources/orbiters/orbiters-logo.gif': 458,
#  '/shuttle/technology/images/srb_mod_compare_6-small.gif': 174,
#  '/history/apollo/sa-10/sa-10.html': 5,
#  '/shuttle/missions/sts-64/sts-64-patch-small.gif': 30,
#  '/shuttle/resources/orbiters/enterprise-logo.gif': 42,
#  '/shuttle/missions/sts-70/images/KSC-95EC-0515.gif': 25,
#  '/history/apollo/apollo-15/images/71HC1144.GIF': 2,
#  '/shuttle/missions/sts-missions-flown.txt': 16,
#  '/images/STS-5.JPG': 10,
#  '/history/skylab/skylab-logo.gif': 34,
#  '/shuttle/technology/images/srb_mod_compare_1-small.gif': 172,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1012.gif': 12,
#  '/history/apollo/apollo-5/apollo-5-info.html': 8,
#  '/shuttle/missions/sts-56/sts-56-patch-small.gif': 18,
#  '/history/apollo/apollo-17/': 12,
#  '/facts/facts.html': 78,
#  '/shuttle/missions/sts-41/sts-41-patch-small.gif': 14,
#  '/shuttle/missions/61-c/61-c-patch-small.gif': 52,
#  '/history/gemini/images/gemini-logo.gif': 64,
#  '/shuttle/missions/sts-59/mission-sts-59.html': 47,
#  '/images/lps-small.gif': 13,
#  '/history/apollo/sa-3/sa-3.html': 7,
#  '/history/apollo/flight-summary.txt': 83,
#  '/images/vab-medium.gif': 17,
#  '/shuttle/missions/51-l/images/850128.GIF': 24,
#  '/elv/TITAN/mars3s.jpg': 24,
#  '/shuttle/missions/sts-49/sts-49-patch-small.gif': 44,
#  '/shuttle/missions/sts-69/endeavour-pad-prelaunch-8-31-95.gif': 117,
#  '/facts/faq.html': 3,
#  '/persons/astronauts/u-to-z/WilliamsDE.txt': 1,
#  '/facilities/saef2.html': 5,
#  '/history/gemini/gemini-2/gemini-2-info.html': 2,
#  '/cgi-bin/imagemap/countdown69?393,290': 1,
#  '/shuttle/countdown/lps/fr.html': 127,
#  '/cgi-bin/imagemap/countdown69?345,286': 1,
#  '/shuttle/missions/sts-59/sts-59-patch-small.gif': 34,
#  '/pub/winvn/readme.txt': 82,
#  '/shuttle/missions/sts-70/movies/movies.html': 97,
#  '/cgi-bin/imagemap/countdown69?63,161': 1,
#  '/history/apollo/apollo-1/apollo-1-info.html': 35,
#  '/shuttle/missions/41-d/': 2,
#  '/shuttle/countdown': 19,
#  '/shuttle/missions/sts-74/mission-sts-74.html': 111,
#  '/shuttle/missions/sts-63/mission-sts-63.html': 82,
#  '/shuttle/countdown/video/livevideo.jpeg': 191,
#  '/shuttle/technology/sts-newsref/spacelab.html': 38,
#  '/facilities/mlp.html': 87,
#  '/history/astp/astp-patch-small.gif': 39,
#  '/shuttle/missions/sts-70/images/KSC-95EC-0705.txt': 2,
#  '/history/mercury/mr-3/mr-3.html': 56,
#  '/elv/ATLAS_CENTAUR/atlas.gif': 119,
#  '/images/vab-small.gif': 127,
#  '/shuttle/missions/51-d/mission-51-d.html': 14,
#  '/shuttle/missions/sts-72/sts-72-info.html': 15,
#  '/shuttle/missions/sts-68/sts-68-patch-small.gif': 92,
#  '/shuttle/missions/sts-36/sts-36-patch-small.gif': 13,
#  '/elv/whnew.htm': 18,
#  '/shuttle/technology/sts-newsref/sts-lcc.html': 146,
#  '/shuttle/missions/sts-66/mission-sts-66.html': 72,
#  '/history/apollo/images/little-joe.gif': 41,
#  '/shuttle/missions/sts-55/sts-55-patch-small.gif': 14,
#  '/cgi-bin/imagemap/countdown69?183,287': 1,
#  '/shuttle/missions/sts-76/mission-sts-76.html': 43,
#  '/history/apollo/images/footprint.gif': 40,
#  '/images/': 461,
#  '/shuttle/missions/100th.html': 13,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0911.jpg': 30,
#  '/htbin/wais.pl?images%2Cearth': 1,
#  '/shuttle/missions/41-b/': 4,
#  '/shuttle/missions/sts-69/images/KSC-95EC-0969.gif': 18,
#  '/cgi-bin/imagemap/countdown69?185,285': 2,
#  '/history/apollo/apollo-12/videos/moonflag.mpg': 4,
#  '/images/cdrom-1-95/img0082.jpg': 1,
#  '/software/': 13,
#  '/history/apollo/images/APOLLO-logosmall.gif': 83,
#  '/shuttle/missions/sts-34/movies/': 3,
#  '/shuttle/technology/images/sts_spec_6-small.gif': 64,
#  '/software/webadmin/payload.txt': 2,
#  '/elv/DELTA/del181s.gif': 33,
#  '/shuttle/missions/51-j/mission-51-j.html': 21,
#  '/history/skylab/skylab.html': 97,
#  '/shuttle/missions/sts-1/sts-1-patch-small.gif': 88,
#  '/history/apollo/apollo-1/images/67HC33a.gif': 12,
#  '/history/apollo/apollo-11/images/69HC973.GIF': 6,
#  '/shuttle/technology/sts-newsref/sts-subs.html': 20,
#  '/history/apollo/apollo-sa.html': 38,
#  '/history/apollo/apollo-1/sounds/': 16,
#  '/shuttle/resources/orbiters/atlantis.gif': 5,
#  '/shuttle/missions/sts-61/mission-sts-61.html': 29,
#  '/shuttle/missions/sts-68/images/ksc-upclose.gif': 97,
#  '/shuttle/missions/sts-39/docs/': 1,
#  '/history/apollo/apollo-12/movies/': 6,
#  '/shuttle/missions/41-d/images/84HC598.GIF': 1,
#  '/shuttle/technology/sts-newsref/sts-msfc.html': 18,
#  '/images/cm-map.gif': 10,
#  '/history/apollo/apollo-1/apollo-1.html': 96,
#  '/history/gemini/gemini-xii/gemini-xii-info.html': 8,
#  '/shuttle/missions/sts-72/sts-72-patch-small.gif': 81,
#  '/elv/PEGASUS/minpeg1.gif': 125,
#  '/shuttle/technology/images/tal_abort_2-small.gif': 41,
#  '/htbin/wais.pl?STS-59': 1,
#  '/cgi-bin/imagemap/countdown69?71,153': 1,
#  '/shuttle/countdown/lps/fr.gif': 114,
#  '/shuttle/missions/sts-35/mission-sts-35.html': 17,
#  '/cgi-bin/imagemap/countdown69?284,290': 1,
#  '/history/apollo/apollo-13/images/70HC507.GIF': 12,
#  '/history/apollo/sa-1/sa-1-patch-small.gif': 16,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0423.txt': 4,
#  '/shuttle/missions/sts-37/mission-sts-37.html': 20,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0544.jpg': 9,
#  '/shuttle/missions/51-l/mission-51-l.html': 127,
#  '/history/apollo/apollo-11/apollo-11-patch.jpg': 19,
#  '/shuttle/missions/sts-70/sts-70-info.html': 8,
#  '/shuttle/missions/sts-71/sts-71-info.html': 21,
#  '/shuttle/missions/sts-69/countdown.html': 66,
#  '/finance/book.gif': 68,
#  '/persons/astronauts/a-to-d/BoldenCF.txt': 10,
#  '/shuttle/technology/sts-newsref/sts_eclss.html': 18,
#  '/history/apollo/apollo-13/sounds/a13_004.wav': 20,
#  '/shuttle/missions/sts-78/mission-sts-78.html': 99,
#  '/images/ksclogo.gif': 114,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0950.gif': 7,
#  '/history/apollo/apollo-12/images/69HC1344.GIF': 8,
#  '/shuttle/missions/sts-32/sts-32-patch-small.gif': 10,
#  '/procurement/midrange/notices/equip/rfqmary.htm': 2,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0443.jpg': 12,
#  '/procurement/midrange/rfo.htm': 17,
#  '/facilities/crawler.html': 27,
#  '/history/gemini/gemini-4/gemini-4-patch-small.gif': 14,
#  '/shuttle/missions/sts-71/sts-71-patch.jpg': 12,
#  '/shuttle/missions/sts-5/sts-5-patch-small.gif': 12,
#  '/shuttle/missions/sts-71/images/index71.gif': 21,
#  '/history/skylab/skylab-station.txt': 22,
#  '/elv/DELTA/euves.jpg': 25,
#  '/shuttle/missions/sts-70/images/images.html': 184,
#  '/shuttle/missions/sts-66/sts-66-patch-small.gif': 70,
#  '/images/launchpalms-small.gif': 160,
#  '/facts/about_ksc.html': 139,
#  '/software/winvn/userguide/winvnsm.gif': 48,
#  '/history/apollo/apollo-15/apollo-15-patch-small.gif': 30,
#  '/ksc.html/facts/about_ksc.html': 2,
#  '/history/apollo/apollo-17/apollo-17-info.html': 16,
#  '/shuttle/missions/sts-59/': 2,
#  '/shuttle/missions/sts-69/images/KSC-95EC-0760.jpg': 62,
#  '/history/gemini/gemini-1/gemini-1-patch-small.gif': 20,
#  '/images/lcc-small2.gif': 64,
#  '/history/gemini/flight-summary.txt': 14,
#  '/software/winvn/userguide/docsrigh.gif': 19,
#  '/shuttle/missions/sts-2/mission-sts-2.html': 19,
#  '/images/landing-small.gif': 90,
#  '/elv/ATLAS_CENTAUR/goess.jpg': 22,
#  '/history/astp/astp-spacecraft.txt': 18,
#  '/shuttle/missions/sts-71/movies/sts-71-rollover.mpg': 16,
#  '/images/op-logo-small.gif': 58,
#  '/history/gemini/gemini-viii/gemini-viii.html': 18,
#  '/cgi-bin/imagemap/countdown69?54,221': 1,
#  '/htbin/wais.pl?51-L': 12,
#  '/mdss/MDSS.html': 81,
#  '/elv/uncons.htm': 35,
#  '/history/apollo/apollo-12/': 12,
#  '/history/apollo/as-203/as-203-patch.jpg': 5,
#  '/history/apollo/apollo-17/images/72HC941.GIF': 6,
#  '/history/apollo/apollo-11/images/69HC680.GIF': 8,
#  '/shuttle/technology/sts-newsref/sts-inst.html': 15,
#  '/images/whatsnew.gif': 103,
#  '/payloads/org/cm.html': 1,
#  '/shuttle/missions/sts-75/sts-75-patch-small.gif': 47,
#  '/software/techdoc/td-Contents.html': 1,
#  '/shuttle/resources/orbiters/columbia.gif': 6,
#  '/history/mercury/mr-4/mr-4-patch.gif': 5,
#  '/shuttle/technology/sts-newsref/sts_mes.html': 42,
#  '/cgi-bin/imagemap/countdown69?71,252': 1,
#  '/cgi-bin/imagemap/countdown69?294,285': 2,
#  '/shuttle/missions/sts-70/images/DSC-95EC-0001.jpg': 22,
#  '/shuttle/technology/images/et-intertank_1-small.gif': 37,
#  '/cgi-bin/imagemap/countdown69?71,189': 2,
#  '/history/apollo/apollo-8/images/69HC21.GIF': 5,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1018.jpg': 13,
#  '/shuttle/technology/images/mission_profile_2-small.gif': 97,
#  '/software/winvn/faq/WINVNFAQ-I-6.html': 13,
#  '/htbin/wais.pl?INTELSAT-VI-RESCUE': 4,
#  '/shuttle/missions/sts-67/images/KSC-95EC-0381.gif': 4,
#  '/shuttle/missions/sts-70/movies/sts-70-launch.mpg': 25,
#  '/history/apollo/apollo-13/sounds/': 49,
#  '/shuttle/missions/rollbacks.html': 76,
#  '/shuttle/': 34,
#  '/shuttle/missions/sts-69/sts-69-patch.jpg': 55,
#  '/shuttle/missions/sts-73/rollover.jpeg': 3,
#  '/shuttle/technology/sts-newsref/sts-gnnc.html': 30,
#  '/images/rollout.gif': 20,
#  '/history/apollo/apollo-missions.txt': 2,
#  '/shuttle/missions/sts-54/mission-sts-54.html': 13,
#  '/history/apollo/pad-abort-test-2/pad-abort-test-2.html': 4,
#  '/shuttle/missions/61-a/61-a-patch-small.gif': 18,
#  '/persons/astronauts/m-to-p/NelsonGD.txt': 1,
#  '/shuttle/missions/sts-69/sts-69-press-kit.txt': 74,
#  '/history/apollo/apollo-11/sounds/A01106AA.WAV': 15,
#  '/cgi-bin/imagemap/countdown69?403,285': 2,
#  '/history/gemini/gemini-goals.txt': 15,
#  '/news/nasa.nasamail.p/571': 1,
#  '/shuttle/missions/sts-45/sts-45-patch-small.gif': 18,
#  '/history/apollo/apollo-13/images/70HC517.GIF': 20,
#  '/shuttle/missions/sts-67/images/images.html': 28,
#  '/shuttle/missions/sts-26/sts-26-patch-small.gif': 21,
#  '/shuttle/countdown/countdown.html': 224,
#  '/history/apollo/apollo-11/images/69HC683.GIF': 7,
#  '/shuttle/missions/51-f/mission-51-f.html': 8,
#  '/shuttle/missions/sts-71/movies/crew-arrival-t38.mpg': 45,
#  '/shuttle/missions/61-b/mission-61-b.html': 32,
#  '/shuttle/technology/sts-newsref/sts-eps.html': 49,
#  '/shuttle/missions/41-g/41-g-patch-small.gif': 15,
#  '/shuttle/missions/sts-67/sts-67-patch-small.gif': 65,
#  '/shuttle/missions/sts-69/images/KSC-95EC-0694.gif': 81,
#  '/shuttle/missions/sts-71/movies/crew-arrival.mpg': 6,
#  '/shuttle/countdown/count70.gif': 31,
#  '/shuttle/missions/sts-73/news/': 35,
#  '/elv/SCOUT/scout.gif': 97,
#  '/shuttle/missions/sts-6/mission-sts-6.html': 22,
#  '/shuttle/missions/51-i/images/85HC346.GIF': 1,
#  '/news/sci.space.news/archive/sci-space-news-16-oct-1993-15.txt': 1,
#  '/shuttle/missions/51-a/': 2,
#  '/shuttle/missions/sts-69/images/index69.gif': 61,
#  '/history/apollo/apollo-7/apollo-7.html': 38,
#  '/history/mercury/mr-3/mr-3-patch.gif': 13,
#  '/finance/webserch.gif': 56,
#  '/history/mercury/ma-6/ma-6.html': 27,
#  '/shuttle/missions/sts-74/sts-74-patch-small.gif': 100,
#  '/cgi-bin/imagemap/fr?425,172': 1,
#  '/history/gemini/gemini-overview.txt': 10,
#  '/elv/SCOUT/elvhead2.gif': 3,
#  '/shuttle/missions/41-b/41-b-patch-small.gif': 11,
#  '/facilities/lf.html': 3,
#  '/cgi-bin/imagemap/countdown69?288,291': 2,
#  '/payloads/processing/vpart7s.gif': 1,
#  '/history/apollo/apollo-4/apollo-4.html': 37,
#  '/shuttle/missions/sts-69/rsrm-joint.jpeg': 15,
#  '/software/winvn/userguide/winvn30.gif': 4,
#  '/history/apollo/apollo-11/images/69HC1119.GIF': 4,
#  '/shuttle/missions/100th.txt': 4,
#  '/shuttle/missions/51-j/news/': 2,
#  '/images/opf-logo.gif': 38,
#  '/procurement/procurement.html': 58,
#  '/facilities/crawlerway.html': 14,
#  '/htbin/wais.pl?IMAX': 20,
#  '/software/winvn/userguide/3_6.htm': 2,
#  '/shuttle/missions/sts-51/sts-51-patch-small.gif': 15,
#  '/shuttle/missions/sts-68/ksc-srl-image.html': 114,
#  '/shuttle/missions/51-c/51-c-patch-small.gif': 22,
#  '/shuttle/missions/sts-27/mission-sts-27.html': 19,
#  '/shuttle/missions/sts-72/sts-72-patch.jpg': 2,
#  '/images/faq.gif': 180,
#  '/shuttle/missions/sts-78/sounds/': 3,
#  '/images/cdrom-1-95/img0001.jpg': 3,
#  '/shuttle/resources/orbiters/atlantis-logo.gif': 68,
#  '/cgi-bin/imagemap/countdown69?78,185': 1,
#  '/shuttle/technology/sts-newsref/sts-cron.html': 43,
#  '/software/winvn/userguide/previous.gif': 1,
#  '/images/crawlerway-logo.gif': 10,
#  '/cgi-bin/imagemap/countdown69?72,218': 2,
#  '/htbin/wais.pl?MIR-Rendezvous': 2,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1059.gif': 10,
#  '/shuttle/missions/sts-71/movies/sts-71-undocking.mpg': 10,
#  '/facilities/opf.html': 36,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1020.gif': 6,
#  '/elv/TITAN/titan.gif': 110,
#  '/history/apollo/apollo-17/images/721200.GIF': 8,
#  '/cgi-bin/imagemap/countdown69?75,186': 2,
#  '/shuttle/technology/images/et-lox_1-small.gif': 32,
#  '/shuttle/technology/images/sts_body_2-small.gif': 69,
#  '/cgi-bin/imagemap/countdown69?63,152': 1,
#  '/history/apollo/apollo-11/movies/': 18,
#  '/shuttle/missions/sts-73/news': 21,
#  '/whats-new.html': 126,
#  '/history/gemini/gemini-vii/gemini-vii.html': 19,
#  '/facilities/lcc.html': 77,
#  '/software/winvn/userguide/A_3.htm': 2,
#  '/images/rollback.gif': 78,
#  '/shuttle/missions/sts-69/news': 56,
#  '/elv/ATLAS_CENTAUR/atlprev.htm': 9,
#  '/shuttle/missions/sts-69/movies/ws-animation-retrieval.mpg': 82,
#  '/images/mlp.gif': 15,
#  '/finance//brrow_1t.gif': 19,
#  '/history/apollo/apollo-13/images/70HC431.GIF': 22,
#  '/icons/movie.xbm': 74,
#  '/persons/astronauts/e-to-h/HartsfieldHW.txt': 2,
#  '/shuttle/countdown/video/sts-69-prelaunch-pad.gif': 141,
#  '/history/apollo/apollo-12/images/69HC1324.GIF': 2,
#  '/shuttle/missions/sts-27/news': 2,
#  '/images/landing.jpg': 19,
#  '/history/apollo/apollo-4/': 2,
#  '//shuttle/missions/sts-71/sts-71-day-01-highlights.html': 1,
#  '/history/apollo/apollo-13/apollo-13-patch.jpg': 39,
#  '/cgi-bin/imagemap/countdown69?61,183': 1,
#  '/facts/faq12.html': 33,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0918.jpg': 21,
#  '/images/mlp-logo.gif': 65,
#  '/cgi-bin/imagemap/countdown69?72,219': 2,
#  '/history/apollo/apollo-9/apollo-9.html': 28,
#  '/facilities/vab.html': 116,
#  '/history/gemini/gemini-xii/gemini-xii-patch-small.gif': 22,
#  '/elv/DELTA/delta.gif': 121,
#  '/shuttle/missions/sts-74/news/': 20,
#  '/htbin/wais.pl?mortin+': 1,
#  '/history/apollo/apollo-13/movies/': 46,
#  '/shuttle/missions/sts-73/docs/': 4,
#  '/shuttle/missions/sts-76/': 6,
#  '/software/winvn/userguide/wvnguide.html': 38,
#  '/shuttle/missions/sts-68/images/ksc.gif': 113,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0912.gif': 13,
#  '/elv/DELTA/deprev.htm': 12,
#  '/history/apollo/apollo-13/docs/': 39,
#  '/shuttle/missions/sts-58/mission-sts-58.html': 5,
#  '/images/slf-logo.gif': 22,
#  '/history/apollo/apollo-6/apollo-6-patch-small.gif': 20,
#  '/history/apollo/apollo-11/images/69HC895.GIF': 2,
#  '/history/skylab/skylab-2.html': 33,
#  '/htbin/wais.pl?DXS': 1,
#  '/history/apollo/apollo-8/images/': 8,
#  '/shuttle/missions/51-a/mission-51-a.html': 16,
#  '/images/de-logo.jpg': 2,
#  '/shuttle/missions/sts-68/ksc-upclose.gif': 12,
#  '/history/apollo/apollo-11/images/69HC761.GIF': 8,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1060.jpg': 16,
#  '/cgi-bin/imagemap/countdown69?56,193': 1,
#  '/history/apollo/apollo-11/docs/': 6,
#  '/images/IMPACT.JPG': 24,
#  '/shuttle/missions/sts-69/movies/': 10,
#  '/images/KSC-94EC-412-small.gif': 72,
#  '/shuttle/missions/sts-26/mission-sts-26.html': 30,
#  '/cgi-bin/imagemap/countdown69?68,185': 2,
#  '/history/apollo/apollo-15/apollo-15-info.html': 17,
#  '/history/apollo/apollo-16/apollo-16-info.html': 5,
#  '/htbin/wais.pl?spacecamp': 1,
#  '/history/apollo/apollo-17/images/73HC182.GIF': 9,
#  '/shuttle/countdown/lps/c-3-4/c-3-4.html': 4,
#  '/history/apollo/apollo-17/apollo-17-patch-small.gif': 57,
#  '/finance/ref_btn.gif': 48,
#  '/shuttle/missions/sts-71/images/images.html': 185,
#  '/history/rocket-history.txt': 75,
#  '/shuttle/technology/images/et_1-small.gif': 36,
#  '/htbin/imagemap/Jul95stats_r?294,89': 1,
#  '/mdss/s_md-2.gif': 67,
#  '/shuttle/missions/51-b/mission-51-b.html': 9,
#  '/shuttle/technology/sts-newsref/sts_overview.html': 82,
#  '/cgi-bin/imagemap/countdown69?332,288': 1,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1019.gif': 7,
#  '/history/apollo/apollo-13/news/': 27,
#  '/msfc/description/instruments/wuppe-button.gif': 7,
#  '/software/winvn/faq/WINVNFAQ-Contents.html': 67,
#  '/history/skylab/skylab-4.html': 23,
#  '/history/apollo/apollo-13/images/': 71,
#  '/shuttle/missions/61-a/mission-61-a.html': 18,
#  '/shuttle/missions/sts-57/mission-sts-57.html': 17,
#  '/cgi-bin/imagemap/countdown69?458,313': 1,
#  '/images/p263_150.gif': 2,
#  '/history/gemini/gemini-spacecraft.txt': 30,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0946.jpg': 16,
#  '/shuttle/missions/sts-73/sts-73-info.html': 30,
#  '/shuttle/art/mailbox.gif': 1,
#  '/shuttle': 7,
#  '/history/apollo/apollo-5/': 2,
#  '/shuttle/missions/sts-51/movies/': 3,
#  '/procurement/expo95.htm': 5,
#  '/payloads/documents/e1365.pdf': 2,
#  '/shuttle/missions/51-l/': 62,
#  '/history/apollo/apollo-11/apollo-11-info.html': 35,
#  '/history/apollo/apollo-16/images/72HC277.GIF': 3,
#  '/shuttle/missions/sts-69/erin.gif': 42,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1019.jpg': 9,
#  '/shuttle/missions/sts-48/mission-sts-48.html': 12,
#  '/msfc/astro_home.html': 31,
#  '/shuttle/missions/sts-54/sts-54-patch-small.gif': 10,
#  '/images/cm.gif': 4,
#  '/finance/bmarcube.gif': 17,
#  '/shuttle/missions/sts-40/sts-40-patch-small.gif': 15,
#  '/shuttle/missions/sts-30/sts-30-patch-small.gif': 12,
#  '/history/mercury/flight-summary.txt': 25,
#  '/history/apollo/sa-4/sa-4.html': 4,
#  '/images/landing-logo.gif': 41,
#  '/shuttle/missions/sts-71/sts-71-press-kit.txt': 28,
#  '/cgi-bin/imagemap/countdown69?72,158': 2,
#  '/history/apollo/a-001/a-001-patch-small.gif': 11,
#  '/shuttle/missions/sts-69/images/KSC-95EC-0969.txt': 8,
#  '/shuttle/missions/sts-73/images/': 8,
#  '/shuttle/missions/sts-29/mission-sts-29.html': 14,
#  '/history/skylab/skylab-4-small.gif': 21,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1014.gif': 7,
#  '/history/apollo/apollo-16/apollo-16-patch-small.gif': 22,
#  '/history/apollo/pad-abort-test-1/pad-abort-test-1.html': 9,
#  '/shuttle/missions/sts-60/sts-60-patch-small.gif': 13,
#  '/robots.txt': 4,
#  '/cgi-bin/imagemap/countdown69?349,288': 2,
#  '/history/apollo/a-003/a-003.html': 3,
#  '/shuttle/missions/sts-71/movies/sts-71-launch-2.mpg': 10,
#  '/shuttle/missions/sts-75/mission-sts-75.html': 50,
#  '/shuttle/missions/41-c/images/84HC176.GIF': 1,
#  '/images/press-site-logo.gif': 5,
#  '/shuttle/countdown/lps/images/BKUP-INT.gif': 4,
#  '/shuttle/missions/51-l/images/86HC159.GIF': 28,
#  '/history/apollo/apollo-4/apollo-4-info.html': 6,
#  '/elv/uplink.htm': 25,
#  '/cgi-bin/imagemap/countdown69?63,221': 3,
#  '/shuttle/missions/sts-58/': 1,
#  '/shuttle/missions/sts-5/news/': 1,
#  '/shuttle/missions/sts-1/': 12,
#  '/history/apollo/apollo-8/movies/': 8,
#  '/shuttle/missions/sts-28/mission-sts-28.html': 13,
#  '/history/apollo/apollo-7/apollo-7-patch-small.gif': 26,
#  '/shuttle/missions/41-g/mission-41-g.html': 10,
#  '/history/apollo/apollo-12/apollo-12.html': 37,
#  '/history/apollo/apollo-13/images/70HC353.GIF': 20,
#  '/history/mercury/ma-9/ma-9.html': 24,
#  '/htbin/wais.pl?ufo': 1,
#  '/history/apollo/images/apollo-insignia.gif': 28,
#  '/cgi-bin/imagemap/fr?203,266': 1,
#  '/history/apollo/apollo-11/sounds/': 14,
#  '/elv/TITAN/mars1s.jpg': 36,
#  '/history/apollo/apollo-5/apollo-5.html': 21,
#  '/shuttle/missions/sts-71/movies/sts-71-mir-dock.mpg': 36,
#  '/cgi-bin/imagemap/countdown69?177,285': 3,
#  '/history/apollo/apollo-1/images/': 16,
#  '/cgi-bin/imagemap/countdown69?79,188': 1,
#  '/shuttle/missions/sts-53/sts-53-patch-small.gif': 8,
#  '/procurement/midrange/notices/equip/ifb39.htm': 5,
#  '/history/gemini/gemini-xi/gemini-xi-patch-small.gif': 10,
#  '/history/gemini/gemini-xi/gemini-xi.html': 15,
#  '/cgi-bin/imagemap/countdown69?172,285': 1,
#  '/shuttle/missions/sts-63/sts-63-patch-small.gif': 63,
#  '/shuttle/missions/sts-76/sts-76-info.html': 4,
#  '/shuttle/missions/sts-50/sts-50-patch-small.gif': 12,
#  '/cgi-bin/imagemap/countdown69?220,42': 1,
#  '/shuttle/technology/sts-newsref/sts_egress.html': 42,
#  '/elv/DELTA/rosats.jpg': 23,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1058.jpg': 9,
#  '/users': 1,
#  '/shuttle/missions/sts-67/images/KSC-95EC-0381.jpg': 3,
#  '/shuttle/technology/images/launch_sites_8-small.gif': 58,
#  '/shuttle/missions/sts-40/images/91HC417.GIF': 1,
#  '/persons/nasa-cm/jmd.html': 24,
#  '/history/gemini/gemini-3/gemini-3-patch-small.gif': 20,
#  '/history/apollo/apollo-13/sounds/a13_002.wav': 23,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1017.jpg': 18,
#  '/cgi-bin/imagemap/countdown69?60,225': 2,
#  '/software/winvn/userguide/winvn1.gif': 4,
#  '/cgi-bin/imagemap/countdown69?68,219': 2,
#  '/finance/toairpla.gif': 44,
#  '/icon/constr.gif': 59,
#  '/shuttle/missions/sts-70/news': 2,
#  '/cgi-bin/imagemap/countdown69?74,219': 3,
#  '/shuttle/resources/orbiters/endeavour.gif': 24,
#  '/history/apollo/apollo-15/images/71HC996.GIF': 8,
#  '/history/apollo/apollo-8/apollo-8-patch-small.gif': 36,
#  '/msfc/astro_home3.gif': 35,
#  '/software/winvn/userguide/winvn23.gif': 3,
#  '/shuttle/missions/41-d/mission-41-d.html': 22,
#  '/shuttle/missions/sts-39/images/91HC371.GIF': 2,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0917.jpg': 14,
#  '/pub/win3/winvn/wv16_99.04.zip': 1,
#  '/shuttle/missions/41-b/news': 2,
#  '/shuttle/missions/sts-67/mission-sts-67.html': 58,
#  '/history/gemini/gemini-3/gemini-3.html': 19,
#  '/programs/indcan/csa.html': 1,
#  '/images/lc39a.gif': 31,
#  '/shuttle/missions/sts-78/': 13,
#  '/history/mercury/mercury-spacecraft.txt': 39,
#  '/cgi-bin/imagemap/countdown69?64,151': 2,
#  '/history/gemini/gemini-v/gemini-v.html': 22,
#  '/shuttle/countdown/lps/osr/osr.html': 22,
#  '/shuttle/missions/sts-48/': 3,
#  '/history/apollo/sa-8/sa-8.html': 3,
#  '/shuttle/countdown/images/countclock.jpeg': 38,
#  '/facts/launch-pass.txt': 8,
#  '/images/op.gif': 4,
#  '/shuttle/missions/sts-77/sts-77-patch-small.gif': 37,
#  '/cgi-bin/imagemap/countdown69?63,188': 3,
#  '/shuttle/missions/sts-67/images/KSC-95EC-0392.gif': 4,
#  '/shuttle/missions/sts-69/': 65,
#  '/history/apollo/apollo-14/images/71HC292.GIF': 3,
#  '/images/bluemarb.gif': 17,
#  '/shuttle/countdown/lps/images/AB-ROW.gif': 5,
#  '/shuttle/missions/sts-70/images/KSC-95EC-0768.jpg': 13,
#  '/mdss/s_md-1.gif': 12,
#  '/history/apollo/apollo-1/images/67HC33.gif': 14,
#  '/history/apollo/apollo-12/apollo-12-patch-small.gif': 24,
#  '/history/apollo/apollo-17/images/72HC981.GIF': 10,
#  '/cgi-bin/imagemap/countdown69?69,225': 1,
#  '/history/apollo/apollo-14/apollo-14.html': 36,
#  '/shuttle/missions/sts-70/images/holes-in-et.jpg': 2,
#  '/cgi-bin/imagemap/countdown69?70,189': 5,
#  '/images/shuttlepad.gif': 6,
#  '/facilities/sspf.html': 6,
#  '/history/apollo/apollo-13/sounds/a13_003.wav': 19,
#  '/shuttle/missions/sts-74/': 16,
#  '/shuttle/missions/51-c/mission-51-c.html': 23,
#  '/shuttle/missions/sts-9/': 2,
#  '/history/mercury/mr-4/mr-4.html': 23,
#  '/software/winvn/faq/WINVNFAQ.html': 6,
#  '/shuttle/missions/sts-65/mission-sts-65.html': 49,
#  '/shuttle/missions/sts-52/mission-sts-52.html': 12,
#  '/shuttle/resources': 1,
#  '/shuttle/missions/sts-72/mission-sts-72.html': 65,
#  '/images': 20,
#  '/cgi-bin/imagemap/countdown69?178,286': 2,
#  '/history/apollo/apollo-11/images/69HC905.GIF': 8,
#  '/shuttle/missions/sts-72/sounds/': 4,
#  '/finance/main.htm': 79,
#  '/history/apollo.html': 1,
#  '/history/apollo/apollo-17/videos/': 2,
#  '/cgi-bin/imagemap/countdown70?184,288': 1,
#  '/elv/TITAN/titan.htm': 17,
#  '/shuttle/missions/sts-5/mission-sts-5.html': 11,
#  '/shuttle/missions/sts-74/news': 6,
#  '/shuttle/missions/sts-76/news/': 5,
#  '/cgi-bin/imagemap/countdown69?286,291': 3,
#  '/history/apollo/pad-abort-test-1/news/': 1,
#  '/cgi-bin/imagemap/countdown71?112,173': 1,
#  '/shuttle/technology/sts-newsref/srb.html': 61,
#  '/images/ius.gif': 3,
#  '/shuttle/missions/sts-60/mission-sts-60.html': 15,
#  '/elv/FACILITIES/aepage.htm': 1,
#  '/shuttle/missions/sts-77/mission-sts-77.html': 31,
#  '/facilities/press.html': 10,
#  '/history/apollo/apollo-spacecraft.txt': 110,
#  '/software/winvn/userguide/1_4.htm': 2,
#  '/history/apollo/apollo-8/images/68HC870.GIF': 6,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1014.jpg': 15,
#  '/history/apollo/apollo-13/images/70HC496.GIF': 11,
#  '/shuttle/missions/51-d/images/': 2,
#  '/history/apollo/apollo-13/images/70HC314.GIF': 32,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0907.gif': 2,
#  '/shuttle/movies/': 8,
#  '/shuttle/technology/images/crew_compartment_13-small.gif': 61,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1057.jpg': 13,
#  '/elv/DELTA/delseps.jpg': 8,
#  '/cgi-bin/imagemap/countdown69?78,153': 1,
#  '/shuttle/technology/sts-newsref/sts-av.html': 36,
#  '/cgi-bin/imagemap/countdown71?97,172': 1,
#  '/shuttle/missions/sts-8/mission-sts-8.html': 13,
#  '/shuttle/missions/sts-37/sts-37-patch-small.gif': 20,
#  '/facts/faq04.html': 98,
#  '/mdss/station.gif': 30,
#  '/shuttle/countdown/countdown70.html': 2,
#  '/history/gemini/gemini-viii/gemini-viii-patch-small.gif': 12,
#  '/shuttle/missions/sts-47/mission-sts-47.html': 13,
#  '/shuttle/missions/sts-73/sounds/': 5,
#  '/shuttle/missions/sts-65/sts-65-patch-small.gif': 41,
#  '/procurement/midrange/notices/equip/lrfq161.htm': 3,
#  '/cgi-bin/imagemap/countdown69?336,276': 1,
#  '/shuttle/missions/sts-67/images/KSC-95EC-0395.gif': 1,
#  '/history/apollo/apollo-12/images/69HC1341.GIF': 7,
#  '/history/skylab/skylab-3.html': 16,
#  '/cgi-bin/imagemap/countdown69?339,288': 2,
#  '/software/winvn/userguide/wvnguide.gif': 33,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0874.gif': 2,
#  '/history/skylab/flight-summary.txt': 14,
#  '/cgi-bin/imagemap/countdown69?181,287': 2,
#  '/elv/TITAN/tit2desc.htm': 10,
#  '/shuttle/missions/sts-39/mission-sts-39.html': 11,
#  '/shuttle/resources/': 4,
#  '/history/apollo/apollo-goals.txt': 40,
#  '/images/dual-pad.gif': 27,
#  '/cgi-bin/imagemap/countdown69?292,288': 2,
#  '/finance/brrow_1t.gif': 44,
#  '/statistics/1995/Jul/Jul95_byte.gif': 7,
#  '/elv/DELTA/del181.gif': 6,
#  '/SDG/Experimental/demoweb/return.gif': 6,
#  '/persons/astronauts/i-to-l/': 2,
#  '/shuttle/missions/sts-71/movies/sts-71-hand-shake.mpg': 17,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0423.gif': 20,
#  '/history/apollo/apollo-8/apollo-8.html': 47,
#  '/facilities/lps.html': 7,
#  '/history/apollo/apollo-1/images/67HC21.gif': 11,
#  '/shuttle/technology/sts-newsref/stsover-landing.html': 6,
#  '/history/apollo/a-002/a-002.html': 4,
#  '/shuttle/missions/sts-69/news/': 64,
#  '/history/apollo/apollo-1/images/apollo-1-crew.gif': 10,
#  '/cgi-bin/imagemap/countdown69?58,159': 2,
#  '/history/apollo/apollo-10/apollo-10-patch-small.gif': 27,
#  '/cgi-bin/imagemap/fr': 2,
#  '/cgi-bin/imagemap/countdown69?129,290': 1,
#  '/persons/astronauts/q-to-t/StrekaloG.txt': 1,
#  '/shuttle/missions/sts-70/images/KSC-95EC-0585.jpg': 8,
#  '/history/apollo/apollo-16/images/72HC411.GIF': 1,
#  '/htbin/wais.pl?SAREX': 1,
#  '/statistics/1993/1993.html': 1,
#  '/shuttle/missions/sts-64/mission-sts-64.html': 38,
#  '/shuttle/missions/sts-70/images/KSC-95EC-0515.jpg': 19,
#  '/cgi-bin/imagemap/countdown69?178,285': 3,
#  '/shuttle/missions/51-l/sounds/': 28,
#  '/shuttle/missions/41-g/41-g-patch.jpg': 3,
#  '/cgi-bin/imagemap/countdown69?77,187': 1,
#  '/shuttle/countdown/count.html': 47,
#  '/images/cdrom-1-95/img0003.jpg': 1,
#  '/history/apollo/apollo-1/apollo-1-patch-small.gif': 85,
#  '/shuttle/missions/41-d/images/84HC473.GIF': 2,
#  '/cgi-bin/imagemap/countdown70?335,284': 1,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0874.txt': 1,
#  '/history/apollo/as-203/as-203-patch-small.gif': 11,
#  '/history/gemini/gemini-3/gemini-3-info.html': 6,
#  '/shuttle/missions/manifest.txt': 3,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0885.txt': 1,
#  '/shuttle/missions/sts-51/mission-sts-51.html': 14,
#  '/shuttle/missions/sts-70/images/woodpecker-on-et.gif': 23,
#  '/finance/suit.gif': 58,
#  '/persons/astronauts/a-to-d/CrippenRL.txt': 9,
#  '/statistics/1995/Jul/Jul95_request.gif': 9,
#  '/shuttle/missions/sts-69/sts-69-info.html': 43,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0443.gif': 10,
#  '/history/apollo/apollo-8/apollo-8-info.html': 6,
#  '/shuttle/missions/sts-74/images/': 3,
#  '/history/apollo/apollo-10/': 8,
#  '/history/apollo/apollo-13/movies/apo13damage.mpg': 33,
#  '/history/apollo/sa-5/': 1,
#  '/cgi-bin/imagemap/countdown69?57,219': 1,
#  '/shuttle/missions/sts-70/sts-70-day-01-highlights.html': 2,
#  '/history/apollo/apollo-5/apollo-5-patch-small.gif': 19,
#  '/shuttle/missions/sts-72/': 11,
#  '/shuttle/missions/51-i/51-i-patch-small.gif': 14,
#  '/history/apollo/apollo-15/sounds/': 3,
#  '/shuttle/missions/sts-34/mission-sts-34.html': 18,
#  '/images/launch.gif': 99,
#  '/history/apollo/apollo-16/movies/': 3,
#  '/facilities/spaceport-logo-small.gif': 34,
#  '/gemini/gemini.html': 1,
#  '/shuttle/missions/sts-67/sts-67-info.html': 1,
#  '/images/Nasa-logo.gif': 6,
#  '/shuttle/missions/sts-41/mission-sts-41.html': 8,
#  '/shuttle/missions/sts-53/movies/sts-53-launch.mpg': 31,
#  '/shuttle/technology/images/launch_sites_8.jpg': 3,
#  '/software/winvn/userguide/2_1_6.htm': 2,
#  '/history/apollo/as-201/as-201-patch.jpg': 3,
#  '/images/crawler-logo.gif': 41,
#  '/persons/astronauts/a-to-d/CenkerRJ.txt': 1,
#  '/shuttle/missions/sts-3/sts-3-patch-small.gif': 11,
#  '/images/crawler.gif': 14,
#  '/history/apollo/apollo-16/apollo-16.html': 25,
#  '/cgi-bin/imagemap/countdown69?180,288': 3,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0890.gif': 2,
#  '/cgi-bin/imagemap/countdown69?66,212': 1,
#  '/elv/DELTA/dsolidss.jpg': 32,
#  '/facts/faq10.html': 21,
#  '/history/mercury/': 4,
#  '/shuttle/missions/sts-31/sts-31-patch-small.gif': 10,
#  '/software/winvn/userguide/winvn21.gif': 4,
#  '/statistics/statistics.html': 32,
#  '/history/apollo/apollo-13/videos/': 12,
#  '/history/apollo/apollo-1/movies/': 15,
#  '/statistics/images/newstat.gif': 11,
#  '/shuttle/missions/sts-70/countdown.html': 17,
#  '/cgi-bin/imagemap/countdown69?177,290': 1,
#  '/shuttle/countdown/lps/images/C-7-8.gif': 3,
#  '/cgi-bin/imagemap/countdown69?67,159': 3,
#  '/software/winvn/userguide/3_1_3.htm': 5,
#  '/cgi-bin/imagemap/countdown69?59,219': 1,
#  '/history/apollo/apollo-10/apollo-10-patch.jpg': 2,
#  '/shuttle/missions/sts-71/sts-71-day-01-highlights.html': 17,
#  '/shuttle/missions/sts-69/sounds/': 6,
#  '/shuttle/technology/images/et_1.jpg': 8,
#  '/persons/astronauts/e-to-h/EngleJH.txt': 6,
#  '/shuttle/countdown/lps/images/C-1.gif': 5,
#  '/shuttle/missions/sts-32/images/90HC44.GIF': 2,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0948.txt': 2,
#  '/cgi-bin/imagemap/countdown69?169,280': 1,
#  '/shuttle/missions/sts-71/sts-71-day-02-highlights.html': 6,
#  '/shuttle/missions/sts-70/movies/sts-70-tdrs-deploy.mpg': 11,
#  '/shuttle/missions/sts-70/images/index70.gif': 23,
#  '/payloads/cm-systems.html': 13,
#  '/elv/TITAN/mars2.jpg': 4,
#  '/shuttle/missions/sts-68/sts-68-patch.jpg': 3,
#  '/shuttle/missions/sts-69/images/KSC-95EC-0694.txt': 18,
#  '/history/gemini/gemini-vii/gemini-vii-patch.jpg': 5,
#  '/software/winvn/wvlarge.gif': 47,
#  '/history/apollo/apollo-8/images/68HC731.GIF': 8,
#  '/shuttle/missions/sts-78/sts-78-patch-small.gif': 77,
#  '/shuttle/technology/sts-newsref/stsover-prep.html': 19,
#  '/shuttle/missions/sts-73/movies/': 13,
#  '/cgi-bin/imagemap/countdown69?289,288': 4,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1013.jpg': 18,
#  '/history/apollo/apollo-15/images/': 7,
#  '/shuttle/missions/sts-60/images/': 5,
#  '/history/mercury/ma-9/ma-9-patch-small.gif': 22,
#  '/facts/faq07.html': 11,
#  '/shuttle/technology/sts-newsref/sts-jsc-comm.html': 36,
#  '/cgi-bin/imagemap/countdown69?62,219': 3,
#  '/shuttle/missions/sts-70/sts-70-day-09-highlights.html': 2,
#  '/history/apollo/apollo-1/apollo-1.txt': 5,
#  '/shuttle/missions/sts-74/sts74.gif': 4,
#  '/history/apollo/apollo-13/images/70HC323.GIF': 24,
#  '/history/apollo/apollo-15/movies/': 4,
#  '/cgi-bin/imagemap/countdown69?72,190': 2,
#  '/history/apollo/apollo-13/sounds/a13_005.wav': 15,
#  '/shuttle/missions/sts-70/count70.gif': 13,
#  '/history/apollo/apollo-11/images/69HC788.GIF': 4,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1013.gif': 12,
#  '/elv/DELTA/dsolids.jpg': 7,
#  '/images/imagemaps/stats.map': 2,
#  '/shuttle/missions/51-j/51-j-patch.jpg': 2,
#  '/shuttle/missions/sts-76/sts-76-patch-small.gif': 32,
#  '/images/nasa-logo.gif': 21,
#  '/shuttle/missions/STS-69/mission-STS-69.html': 38,
#  '/shuttle/technology/sts-newsref/sts-lc39.html': 4,
#  '/cgi-bin/imagemap/countdown69?61,221': 2,
#  '/history/astp/astp.html': 42,
#  '/.': 2,
#  '/shuttle/missions/51-l/docs/': 20,
#  '/history/apollo/apollo-14/': 6,
#  '/shuttle/missions/sts-73/': 20,
#  '/htbin/wais.pl?rcs': 2,
#  '/shuttle/technology/sts-newsref/carriers.html': 9,
#  '/history/apollo/apollo-11/images/': 23,
#  '/images/shuttle2.gif': 13,
#  '/images/cm-logo.gif': 20,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0876.gif': 3,
#  '/history/apollo/apollo-15/apollo-15-patch.jpg': 1,
#  '/shuttle/missions/sts-1/mission-sts-2.html': 1,
#  '/history/apollo/apollo-9/images/69HC317.GIF': 1,
#  '/software/winvn/userguide/3_2.htm': 1,
#  '/images/p263_150.jpg': 1,
#  '/software/winvn/userguide/docsleft.gif': 26,
#  '/shuttle/missions/sts-74/movies/': 2,
#  '/history/mercury/mr-4/mr-4-patch-small.gif': 29,
#  '/news/sci.space.news/157': 1,
#  '/shuttle/countdown/launch-team.html': 7,
#  '/history/gemini/gemini-vii/docs/': 1,
#  '/cgi-bin/imagemap/countdown69?60,215': 2,
#  '/payloads/processing/vpart0as.gif': 1,
#  '/payloads/documents/e6058.pdf': 1,
#  '/shuttle/missions/sts-71/sts-71-day-03-highlights.html': 12,
#  '/history/apollo/apollo-5/movies/': 3,
#  '/shuttle/missions/sts-70/woodpecker.html': 24,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0423.jpg': 17,
#  '/software/winvn/faq/WINVNFAQ-I-5.html': 9,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1012.jpg': 24,
#  '/images/STS-8.JPG': 6,
#  '/facilities/slf.html': 34,
#  '/history/apollo/apollo-12/apollo-12-patch.jpg': 2,
#  '/htbin/wais.pl?MAHRSI': 1,
#  '/shuttle/technology/sts-newsref/sts-mps.html': 38,
#  '/mdss/dcy2.gif': 32,
#  '/cgi-bin/imagemap/countdown69?66,223': 1,
#  '/history/apollo/apollo-4/apollo-4-patch-small.gif': 18,
#  '/shuttle/technology/sts-newsref/mission_profile.html': 32,
#  '/shuttle/technology/images/srb_16-small.gif': 71,
#  '/mdss/srqa/qpa/s_qpa.gif': 1,
#  '/elv/ATLAS_CENTAUR/acsun.jpg': 13,
#  '/cgi-bin/imagemap/countdown70?349,286': 1,
#  '/shuttle/missions/sts-7/mission-sts-7.html': 12,
#  '/history/apollo/as-202/as-202-patch-small.gif': 16,
#  '/htbin/wais.pl?shuttle': 3,
#  '/shuttle/missions/sts-70/sts-70-land2.gif': 2,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0915.gif': 9,
#  '/procurement/midrange/equip.htm': 16,
#  '/cgi-bin/imagemap/countdown69?179,287': 3,
#  '/cgi-bin/imagemap/countdown69?64,251': 1,
#  '/elv/DELTA/delta.htm': 39,
#  '/shuttle/missions/sts-48/images/91HC553.GIF': 1,
#  '/shuttle/missions/sts-4/images/82HC356.GIF': 2,
#  '/cgi-bin/imagemap/countdown69?72,223': 2,
#  '/cgi-bin/imagemap/countdown69?348,289': 1,
#  '/shuttle/missions/sts-70/images/KSC-95EC-1059.jpg': 18,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0589.gif': 5,
#  '/shuttle/missions/sts-70/images/KSC-95EC-0992.jpg': 4,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0909.txt': 1,
#  '/shuttle/missions/sts-61/movies/': 2,
#  '/elv/TITAN/mars1.jpg': 6,
#  '/htbin/wais.pl?ICBC': 3,
#  '/cgi-bin/imagemap/countdown69?64,161': 2,
#  '/htbin/wais.pl?depression': 1,
#  '/shuttle/technology/sts-newsref/sts-gear.html': 10,
#  '/shuttle/missions/sts-46/sts-46-patch-small.gif': 9,
#  '/persons/astronauts/a-to-d/DurranceST.html': 2,
#  '/facts/faq06.html': 10,
#  '/images/stats.gif': 5,
#  '/history/apollo/as-201/as-201-patch-small.gif': 24,
#  '/elv/FACILITIES/p-ae.gif': 1,
#  '/shuttle/missions/51-a/51-a-patch-small.gif': 14,
#  '/elv/SCOUT/s_216s.jpg': 27,
#  '/shuttle/missions/sts-52/sts-52-patch-small.gif': 11,
#  '/shuttle/missions/sts-70/movies/sts-70-crew-walkout.mpg': 5,
#  '/history/gemini/movies/gemini-launch.mpg': 36,
#  '/msfc/description/colorbar.gif': 2,
#  '/history/apollo/as-202/images/': 2,
#  '/shuttle/missions/sts-70/movies/sts-70-landing-2.mpg': 10,
#  '/software/winvn/winvn.html.': 4,
#  '/images/263_small.jpg': 11,
#  '/software/winvn/userguide/winvn20.gif': 10,
#  '/htbin/wais.pl?HERCULES': 4,
#  '/shuttle/missions/sts-6/sts-6-patch-small.gif': 10,
#  '/shuttle/missions/sts-48/sts-48-patch-small.gif': 11,
#  '/shuttle/technology/sts-newsref/sts-apu.html': 25,
#  '/shuttle/technology/sts-newsref/stsover-missions.html': 14,
#  '/software/winvn/faq/': 1,
#  '/history/skylab/skylab-1.html': 13,
#  '/images/horz.gif': 8,
#  '/shuttle/missions/51-j/sounds/': 1,
#  '/history/apollo/apollo-8/sounds/': 5,
#  '/history/apollo/apollo-12/images/69HC1007.GIF': 8,
#  '/finance/qmarcube.gif': 10,
#  '/persons/astronauts/m-to-p/MusgraveFS.txt': 2,
#  '/elv/bakgro.gif': 4,
#  '/history/apollo/apollo-1/images/67HC31.gif': 8,
#  '/history/apollo/a-001/a-001-info.html': 4,
#  '/procurement/midrange/notices/equip/doc3735.htm': 5,
#  '/procurement/midrange/notices/equip/mezz.htm': 1,
#  '/cgi-bin/imagemap/onboard?100,193': 1,
#  '/cgi-bin/imagemap/countdown69?294,286': 1,
#  '/cgi-bin/imagemap/countdown69?310,300': 1,
#  '/shuttle/missions/sts-70/images/KSC-95EC-0585.gif': 5,
#  '/cgi-bin/imagemap/countdown69?172,284': 1,
#  '/cgi-bin/imagemap/countdown69?57,155': 3,
#  '/software/winvn/userguide/3_1_2.htm': 5,
#  '/msfc/description/instruments/hut_logo_icon.gif': 2,
#  '/history/gemini/gemini-vi-a/gemini-vi-a-patch-small.gif': 8,
#  '/history/apollo/apollo-13/images/70HC467.GIF': 9,
#  '/shuttle/technology/sts-newsref/sts-caws.html': 10,
#  '/shuttle/missions/51-d/51-d-patch-small.gif': 17,
#  '/shuttle/missions/sts-71/images/KSC-95EC-0916.jpg': 15,
#  '/history/apollo/a-001/images/': 3,
#  '/shuttle/missions/sts-53/mission-sts-53.html': 8,
#  ...}

# %% [markdown]
# ### Representation of Result sorted by value

# %%
import operator
sorted_Result=sorted(Q1Result.items(),key=operator.itemgetter(1),reverse=True)
sorted_Result[:10]
# Out:
# [('/images/NASA-logosmall.gif', 6193),
#  ('/images/KSC-logosmall.gif', 4917),
#  ('/images/MOSAIC-logosmall.gif', 4216),
#  ('/images/WORLD-logosmall.gif', 4212),
#  ('/images/USA-logosmall.gif', 4210),
#  ('/images/ksclogo-medium.gif', 3942),
#  ('/ksc.html', 2782),
#  ('/history/apollo/images/apollo-logo1.gif', 2378),
#  ('/images/launch-logo.gif', 2194),
#  ('/images/ksclogosmall.gif', 1846)]

# %% [markdown]
# ## Question 2 What day were the most HTTP requests made to the server?
# ### Mapper

# %%
Days_Map=[]
for x in df1['DateTime'].str[0:11]:
    Days_Map.append((x,1))
Days_Map
# Out:
# [('15/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('19/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('13/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('04/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('05/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('12/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('09/Aug/1995', 1),
#  ('08/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ('14/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('24/Aug/1995', 1),
#  ('15/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('10/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('28/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('16/Aug/1995', 1),
#  ('22/Aug/1995', 1),
#  ('18/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('29/Aug/1995', 1),
#  ('21/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('06/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('31/Aug/1995', 1),
#  ('27/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('01/Aug/1995', 1),
#  ('17/Aug/1995', 1),
#  ('20/Aug/1995', 1),
#  ('23/Aug/1995', 1),
#  ('25/Aug/1995', 1),
#  ('30/Aug/1995', 1),
#  ('07/Aug/1995', 1),
#  ('11/Aug/1995', 1),
#  ('26/Aug/1995', 1),
#  ...]

# %% [markdown]
# ### Reducer function

# %%
def Reducer_2(Map):
    Result={}
    for key in Map:
        if key[0] in Result.keys():
            Result[key[0]]+=1
        else:
            Result[key[0]]=1
    return Result

# %%
Q2Result=Reducer_2(Days_Map)
Q2Result
# Out:
# {'01/Aug/1995': 2144,
#  '03/Aug/1995': 2575,
#  '04/Aug/1995': 3762,
#  '05/Aug/1995': 1944,
#  '06/Aug/1995': 2094,
#  '07/Aug/1995': 3645,
#  '08/Aug/1995': 3795,
#  '09/Aug/1995': 3734,
#  '10/Aug/1995': 3908,
#  '11/Aug/1995': 3846,
#  '12/Aug/1995': 2364,
#  '13/Aug/1995': 2334,
#  '14/Aug/1995': 3891,
#  '15/Aug/1995': 3744,
#  '16/Aug/1995': 3646,
#  '17/Aug/1995': 3827,
#  '18/Aug/1995': 3600,
#  '19/Aug/1995': 2077,
#  '20/Aug/1995': 2027,
#  '21/Aug/1995': 3502,
#  '22/Aug/1995': 3595,
#  '23/Aug/1995': 3757,
#  '24/Aug/1995': 3334,
#  '25/Aug/1995': 3608,
#  '26/Aug/1995': 2079,
#  '27/Aug/1995': 2109,
#  '28/Aug/1995': 3573,
#  '29/Aug/1995': 4430,
#  '30/Aug/1995': 5106,
#  '31/Aug/1995': 5694}

# %%
import operator
sorted_Result=sorted(Q2Result.items(),key=operator.itemgetter(1),reverse=True)
sorted_Result[:10]
# Out:
# [('31/Aug/1995', 5694),
#  ('30/Aug/1995', 5106),
#  ('29/Aug/1995', 4430),
#  ('10/Aug/1995', 3908),
#  ('14/Aug/1995', 3891),
#  ('11/Aug/1995', 3846),
#  ('17/Aug/1995', 3827),
#  ('08/Aug/1995', 3795),
#  ('04/Aug/1995', 3762),
#  ('23/Aug/1995', 3757)]

# %% [markdown]
# ## Q3 -How many HTTP 200 responses were made?
# ### Map function

# %%
Response_Map=[]
for x in df1['Status']:
    Response_Map.append((x,1))
Response_Map
# Out:
# [('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('302', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ...]

# %% [markdown]
# ### Reducer Function

# %%
def Reducer_3(Map):
    Result={'200':0}
    for key in Map:
        if key[0]=='200':
            Result[key[0]]+=1
    return Result

# %%
Q3Result=Reducer_3(Response_Map)
Q3Result
# Out:
# {'200': 88851}

# %% [markdown]
# ## Q4 How many other HTTP code reposnses were made?
# ### Map function

# %%
# Using the same map as in Q3
Response_Map
# Out:
# [('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('302', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('302', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('404', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ('304', 1),
#  ('200', 1),
#  ('200', 1),
#  ('200', 1),
#  ...]

# %% [markdown]
# ### Reducer Function - using the same function as in Q2

# %%
Q4Response=Reducer_2(Response_Map)
Q4Response
# Out:
# {'200': 88851, '302': 1639, '304': 8596, '403': 12, '404': 644, '501': 2}

# %% [markdown]
# ## Q5 What were the biggest, smallest and average file sizes served?
# ### Map function

# %%
Size_Map=df1['Size'].tolist()

# %% [markdown]
# ### Reduce function

# %%
Q5Result=sorted(Size_Map)

# %%
# Max value
maximum=0
for value in Q5Result:
    if value[0] in '0123456789':
        if int(value)>=maximum:
            maximum=int(value)
print(maximum)
# Out:
# 3155499

# %%
# Min value
for value in Q5Result:
    if value[0] in '0123456789':
        if int(value)>=0:
            print(value)
            break
# Out:
# 0

# %%
def Reducer_3(Map):
    sumMap=0
    counter=0
    for value in Map:
        if value[0] in '0123456789':
            sumMap+=int(value)
            counter+=1
    return sumMap/counter

# %%
# Average file size
Reducer_3(Size_Map)
# Out:
# 17458.765180179267

# %% [markdown]
# ## The Challenge (part B)
#
# By adding your own code in your own Jupyter Notebook cells below (you can add a cell by pressing the + button in the toolbar), try and answer some of the following questions about this data set:
#
# - Which files were most popular in terms of `GET` requests?
# - What day were the most HTTP requests made to the server?
# - How many HTTP 200 (OK) responses were made?
# - How many other HTTP code responses were made? Hint: here is a [list of HTTP response codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - What were the biggest, smallest and average file sizes served?
#
# **Important: I want you to try and complete this exercise using the MapReduce programming model. If you find this too difficult, go ahead an use `pandas` anyway as this is still a very challenging lab.**
#
# If you comfortably work out answers for all of these, feel free to add your own analyses!
#
# When you're finished with lab 7 (or had completed what you can), choose **Save and Checkpoint** from the **File** menu, then choose **Download as Notebook** and save it to your computer or USB stick. You can then send a copy to the lecturer via Slack or email to check over.

# %%
#Most popular files among GET requests
df1.loc[:,['File','Method']].where(df1["Method"]=='GET').groupby('File').count().sort_values(by='Method',ascending=False).head(5)
# Out:
#                               Method
# File
# /images/NASA-logosmall.gif      6193
# /images/KSC-logosmall.gif       4917
# /images/MOSAIC-logosmall.gif    4216
# /images/WORLD-logosmall.gif     4212
# /images/USA-logosmall.gif       4210

# %%
df1['Date']=df1['DateTime'].str[0:11]
df1.head(5)
# Out:
#                 Address              DateTime Timezone Method  \
# 0       159.142.165.138  15/Aug/1995:11:03:22    -0400    GET
# 1         134.131.38.18  22/Aug/1995:13:43:38    -0400    GET
# 2  os2c14.aca.ilstu.edu  31/Aug/1995:21:47:11    -0400    GET
# 3       suba01.suba.com  24/Aug/1995:04:48:23    -0400    GET
# 4       146.138.145.170  08/Aug/1995:16:30:51    -0400    GET
#
#                                               File      HTTP Status   Size  \
# 0  /shuttle/missions/sts-73/sts-73-patch-small.gif  HTTP/1.0    200   4179
# 1  /shuttle/missions/sts-73/sts-73-patch-small.gif  HTTP/1.0    200   4179
# 2  /shuttle/missions/sts-69/sts-69-patch-small.gif  HTTP/1.0    200   8083
# 3                              /htbin/wais.pl?TISP  HTTP/1.0    200   1349
# 4  /shuttle/missions/sts-62/sts-62-patch-small.gif  HTTP/1.0    200  14385
#
#                 IP       IP Address         Country  Latitude  Longitude  \
# 0  159.142.165.138  159.142.165.138   United States   38.8933   -77.0146
# 1    134.131.38.18    134.131.38.18   United States   32.4040   -86.2539
# 2    92.242.132.15    92.242.132.15  United Kingdom   51.4964    -0.1224
# 3   104.160.171.91   104.160.171.91   United States   34.0584  -118.2780
# 4  146.138.145.170  146.138.145.170   United States   38.8933   -77.0146
#
#           City         Date
# 0   Washington  15/Aug/1995
# 1   Montgomery  22/Aug/1995
# 2          NaN  31/Aug/1995
# 3  Los Angeles  24/Aug/1995
# 4   Washington  08/Aug/1995

# %%
df1.groupby('Date').count().sort_values(by='Method',ascending=False)['Method'].head(5)
# Out:
# Date
# 31/Aug/1995    5694
# 30/Aug/1995    5106
# 29/Aug/1995    4430
# 10/Aug/1995    3908
# 14/Aug/1995    3891
# Name: Method, dtype: int64

# %%
df1.where(df1['Status']=='200')['Status'].count()
# Out:
# 88851

# %%
df1['Status'].unique()
# Out:
# array(['200', '304', '302', '404', '403', '501'], dtype=object)

# %%
df1['Size'].str.replace('-','0').astype(int).min()
# Out:
# 0

# %%
df1['Size'].str.replace('-','0').astype(int).max()
# Out:
# 3155499

# %%
df1['Size'].str.replace('-','0').astype(int).mean()
# Out:
# 17301.58308269169

# %% [markdown]
# # Bonus Challenge
#
# If you are feeling *really* adventurous, you can try using a Python library to do geographical-IP lookups to do some analyses. You will need to open up the command line and install the library called `geolite2`. To do this, open **Git Bash** and type the following:
#
# ```
# $  pip install maxminddb-geolite2
# ```
#
# Once `pip` has installed `geolite2`, if you restart Jupyter Notebook, you should be able to use it similar to as follows:

# %%
from geolite2 import geolite2
reader = geolite2.reader()
reader.get('1.0.0.0')
# Out:
# {'city': {'geoname_id': 2151718, 'names': {'en': 'Research'}},
#  'continent': {'code': 'OC',
#   'geoname_id': 6255151,
#   'names': {'de': 'Ozeanien',
#    'en': 'Oceania',
#    'es': 'Oceanía',
#    'fr': 'Océanie',
#    'ja': 'オセアニア',
#    'pt-BR': 'Oceania',
#    'ru': 'Океания',
#    'zh-CN': '大洋洲'}},
#  'country': {'geoname_id': 2077456,
#   'iso_code': 'AU',
#   'names': {'de': 'Australien',
#    'en': 'Australia',
#    'es': 'Australia',
#    'fr': 'Australie',
#    'ja': 'オーストラリア',
#    'pt-BR': 'Austrália',
#    'ru': 'Австралия',
#    'zh-CN': '澳大利亚'}},
#  'location': {'accuracy_radius': 1000,
#   'latitude': -37.7,
#   'longitude': 145.1833,
#   'time_zone': 'Australia/Melbourne'},
#  'postal': {'code': '3095'},
#  'registered_country': {'geoname_id': 2077456,
#   'iso_code': 'AU',
#   'names': {'de': 'Australien',
#    'en': 'Australia',
#    'es': 'Australia',
#    'fr': 'Australie',
#    'ja': 'オーストラリア',
#    'pt-BR': 'Austrália',
#    'ru': 'Австралия',
#    'zh-CN': '澳大利亚'}},
#  'subdivisions': [{'geoname_id': 2145234,
#    'iso_code': 'VIC',
#    'names': {'en': 'Victoria', 'pt-BR': 'Vitória', 'ru': 'Виктория'}}]}

# %% [markdown]
# The `reader.get( ... )` line takes an IP address and looks up the geographical information about it, and returns a Python dictionary. You can now select specific geographical information about the IP address. For example

# %%
# Get the country, in particular the English name
geo_dict = reader.get('1.1.1.1')
geo_dict['country']['names']['en']
# Out:
# 'Australia'

# %%
# Get the continent, in particular the English name
geo_dict = reader.get('1.1.1.1')
geo_dict['continent']['names']['en']
# Out:
# 'Oceania'

# %% [markdown]
# I have not tested this, so I will leave it to you to work out for yourselves if you take on this Bonus Challenge!

# %% [markdown]
# ## Transform alpha addresses to IP addresses

# %%
import socket

# %%
for row in df1.index.values:
    if df1.loc[row,'Address'][0] in '0123456789':
        df1.loc[row,'IP Address']=df1.loc[row,'Address']
    else:
        try:
            df1.loc[row,'IP Address']=socket.gethostbyname(df1.loc[row,'Address'])
        except:
            df1.loc[row,'IP Address']=None

# %%
df1.head(5)
# Out:
#                 Address              DateTime Timezone Method  \
# 0       159.142.165.138  15/Aug/1995:11:03:22    -0400    GET
# 1         134.131.38.18  22/Aug/1995:13:43:38    -0400    GET
# 2  os2c14.aca.ilstu.edu  31/Aug/1995:21:47:11    -0400    GET
# 3       suba01.suba.com  24/Aug/1995:04:48:23    -0400    GET
# 4       146.138.145.170  08/Aug/1995:16:30:51    -0400    GET
#
#                                               File      HTTP Status   Size  \
# 0  /shuttle/missions/sts-73/sts-73-patch-small.gif  HTTP/1.0    200   4179
# 1  /shuttle/missions/sts-73/sts-73-patch-small.gif  HTTP/1.0    200   4179
# 2  /shuttle/missions/sts-69/sts-69-patch-small.gif  HTTP/1.0    200   8083
# 3                              /htbin/wais.pl?TISP  HTTP/1.0    200   1349
# 4  /shuttle/missions/sts-62/sts-62-patch-small.gif  HTTP/1.0    200  14385
#
#                 IP       IP Address
# 0  159.142.165.138  159.142.165.138
# 1    134.131.38.18    134.131.38.18
# 2    92.242.132.15    92.242.132.15
# 3   104.160.171.91   104.160.171.91
# 4  146.138.145.170  146.138.145.170

# %% [markdown]
# ### Get geo_dict using geolite2

# %%
for row in df1.index.values:
    if pd.notnull(df1.loc[row,'IP Address']):
        IP=df1.loc[row,'IP Address']
        try:
            geo_dict = reader.get(IP)
            df1.loc[row,'Country']=geo_dict['country']['names']['en']
            try:
                df1.loc[row,'City']=geo_dict['city']['names']['en']
            except:
                pass
            df1.loc[row,'Latitude']=geo_dict['location']['latitude']
            df1.loc[row,'Longitude']=geo_dict['location']['longitude']
        except:
            pass

# %%
df1.head()
# Out:
#                 Address              DateTime Timezone Method  \
# 0       159.142.165.138  15/Aug/1995:11:03:22    -0400    GET
# 1         134.131.38.18  22/Aug/1995:13:43:38    -0400    GET
# 2  os2c14.aca.ilstu.edu  31/Aug/1995:21:47:11    -0400    GET
# 3       suba01.suba.com  24/Aug/1995:04:48:23    -0400    GET
# 4       146.138.145.170  08/Aug/1995:16:30:51    -0400    GET
#
#                                               File      HTTP Status   Size  \
# 0  /shuttle/missions/sts-73/sts-73-patch-small.gif  HTTP/1.0    200   4179
# 1  /shuttle/missions/sts-73/sts-73-patch-small.gif  HTTP/1.0    200   4179
# 2  /shuttle/missions/sts-69/sts-69-patch-small.gif  HTTP/1.0    200   8083
# 3                              /htbin/wais.pl?TISP  HTTP/1.0    200   1349
# 4  /shuttle/missions/sts-62/sts-62-patch-small.gif  HTTP/1.0    200  14385
#
#                 IP       IP Address         Country  Latitude  Longitude  \
# 0  159.142.165.138  159.142.165.138   United States   38.8933   -77.0146
# 1    134.131.38.18    134.131.38.18   United States   32.4040   -86.2539
# 2    92.242.132.15    92.242.132.15  United Kingdom   51.4964    -0.1224
# 3   104.160.171.91   104.160.171.91   United States   34.0584  -118.2780
# 4  146.138.145.170  146.138.145.170   United States   38.8933   -77.0146
#
#           City
# 0   Washington
# 1   Montgomery
# 2          NaN
# 3  Los Angeles
# 4   Washington

# %% [markdown]
# ### Countries and Cities with most logins

# %%
df1.loc[:,['Status','Country']].groupby('Country').count().sort_values(by='Status',ascending=False).head(10)
# Out:
#                    Status
# Country
# United Kingdom      56230
# United States       27489
# Canada               1859
# Japan                1151
# Germany               809
# Australia             641
# Sweden                436
# Italy                 351
# Brazil                245
# Republic of Korea     230

# %%
df1.loc[:,['Status','City','Country']].groupby(['City','Country']).count().sort_values(by='Status',ascending=False).head(10)
# Out:
#                             Status
# City         Country
# Huntsville   United States    7080
# New York     United States     665
# Cocoa        United States     526
# Chesterfield United States     458
# Ashburn      United States     456
# Titusville   United States     453
# Montgomery   United States     446
# Chicago      United States     418
# Washington   United States     381
# Denver       United States     380

# %% [markdown]
# ### Graph showing Cities with most logins on map - dot size is the number of logins

# %%
USCities=df1.where(df1['Country']=='United States')
lat=USCities.loc[:,['Latitude','City']].groupby('City').mean().sort_index()['Latitude'].tolist()
lon=USCities.loc[:,['Longitude','City']].groupby('City').mean().sort_index()['Longitude'].tolist()
count_start=USCities.loc[:,['Longitude','City']].groupby('City').count().sort_index()['Longitude']
data_range=count_start.max()-count_start.min()
minimum=count_start.min()
count=(((count_start-minimum)/data_range)*20+4).tolist()

# %%
from bokeh.io import output_notebook, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool
)

map_options = GMapOptions(lat=35, lng=-100, map_type="roadmap", zoom=4)

plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options)
plot.title.text = "America"

plot.api_key = ""

source = ColumnDataSource(data=dict(lat=lat,lon=lon,size=count))

circle = Circle(x="lon", y="lat", size="size", fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1d881f30-7657-4076-a43d-f686a8b9f510">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="07583983-cbc8-45af-aacb-ccc3fbd0ac75"></div>
# </div>
